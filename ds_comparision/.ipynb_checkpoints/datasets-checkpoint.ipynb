# %%
import pandas as pd
from pandas.io.json import json_normalize
from pymongo import MongoClient
import matplotlib
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy.stats import kurtosis
from scipy.stats import skew
from scipy import stats  
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
import json
from bson.json_util import dumps

# %%
conn = MongoClient('140.115.53.147', 27017)
conn.database_names()
# Out:
# /usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
# ['CYCU_1031SP',
#  'CYCU_1041SP',
#  'CYCU_1042OS',
#  'CYCU_1051SP',
#  'CYCU_1052OS',
#  'KU_dataset_1',
#  'KU_dataset_2',
#  'NCU_CHKA',
#  'NCU_CHKB',
#  'NCU_ETS',
#  'NCUx107_Pre_college_calculas',
#  'OULAD',
#  'admin',
#  'config',
#  'local',
#  'test']

# %% [markdown]
# # NCUx

# %% [markdown]
# ### NCUx - Freshman calculas

# %%
db = conn['NCU_ETS']
collection = db['ets_final_score']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id final_score   username
# 0  5ba66ac098d846d79444b79d        24.5  104602004
# 1  5ba66ac098d846d79444b79e       74.12  104602005
# 2  5ba66ac098d846d79444b79f       61.13  104602006

# %%
score_df = df['final_score']
score_df = score_df.dropna()
score_df = score_df.astype(float)
ncux_fc = score_df.astype(int)

# %% [markdown]
# ### NCUx - chka

# %%
db = conn['NCU_CHKA']
collection = db['chka_final_score']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id final_score  username
# 0  5ba66abe98d846d79444aa71          30  Y1050167
# 1  5ba66abe98d846d79444aa72          10  Y1050168
# 2  5ba66abe98d846d79444aa73           0  Y1050169

# %%
score_df = df['final_score']
score_df = score_df.dropna()
score_df = score_df.astype(float)
ncux_chka = score_df.astype(int)

# %% [markdown]
# ### NCUx - chkb

# %%
db = conn['NCU_CHKB']
collection = db['chkb_final_score']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id final_score  username
# 0  5ba66abf98d846d79444b191          10  Y1050280
# 1  5ba66abf98d846d79444b192          10  Y1050281
# 2  5ba66abf98d846d79444b193          10  Y1050282

# %%
score_df = df['final_score']
score_df = score_df.dropna()
score_df = score_df.astype(float)
ncux_chkb = score_df.astype(int)

# %% [markdown]
# ### NCUx107_Pre_college_calculas

# %%
db = conn['NCUx107_Pre_college_calculas']
collection = db['students_grades']

#collection_str = dumps(collection.find())
#collection_str = ''.join(collection_list)
#data = json.loads(collection_str)
#json_normalize(data)
#df = pd.DataFrame(list(collection.find()))
#df = df['grades'].to_frame()
#collection_list
# Out:
# [{'_id': ObjectId('5ba65fa698d846d7943d7013'),
#   'bonusGrade': '10.5',
#   'grades': [{'name': '週考一', 'score': 72},
#    {'name': '週考二', 'score': 78},
#    {'name': '週考三', 'score': 59},
#    {'name': '週考四', 'score': 48},
#    {'name': '期末考', 'score': 61}],
#   'name': '81b289dcc218f352b3a33901651cfce5',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107202507'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7014'),
#   'bonusGrade': '11.5',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 78},
#    {'name': '週考三', 'score': 77},
#    {'name': '週考四', 'score': 74},
#    {'name': '期末考', 'score': 73}],
#   'name': '97a05f1efbcadf2c039d1f83c4a5c7c0',
#   'rollCallGrade': '10',
#   'stageGrade': '4',
#   'studentId': '107202510'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7015'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 51},
#    {'name': '週考二', 'score': 93},
#    {'name': '週考三', 'score': 48},
#    {'name': '週考四', 'score': 89},
#    {'name': '期末考', 'score': 83}],
#   'name': '5dd7a481abf9e1cfc06d4b4bca79a88e',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107203503'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7016'),
#   'bonusGrade': '1.5',
#   'grades': [{'name': '週考一', 'score': 59},
#    {'name': '週考二', 'score': 41},
#    {'name': '週考三', 'score': 31},
#    {'name': '週考四', 'score': 33},
#    {'name': '期末考', 'score': 0}],
#   'name': 'c20a2478947da9d12ccbae89873e51f3',
#   'rollCallGrade': '9',
#   'stageGrade': '0',
#   'studentId': '107202505'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7017'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 61},
#    {'name': '週考二', 'score': 48},
#    {'name': '週考三', 'score': 22},
#    {'name': '週考四', 'score': 48},
#    {'name': '期末考', 'score': 78}],
#   'name': 'f21669bcef59a091558f222e932172ff',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107203509'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7018'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 74},
#    {'name': '週考二', 'score': 82},
#    {'name': '週考三', 'score': 60},
#    {'name': '週考四', 'score': 88},
#    {'name': '期末考', 'score': 96}],
#   'name': 'e4383ba7e6025a6765169b4924669491',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107203508'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7019'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 70},
#    {'name': '週考三', 'score': 85},
#    {'name': '週考四', 'score': 69},
#    {'name': '期末考', 'score': 44}],
#   'name': '8924fb4d1a7755bb6d5b0145299d4a40',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107203518'},
#  {'_id': ObjectId('5ba65fa698d846d7943d701a'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 85},
#    {'name': '週考三', 'score': 84},
#    {'name': '週考四', 'score': 94},
#    {'name': '期末考', 'score': 87}],
#   'name': '3e76e5baf086e791ddaa808f719ec4eb',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107203516'},
#  {'_id': ObjectId('5ba65fa698d846d7943d701b'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 75},
#    {'name': '週考二', 'score': 46},
#    {'name': '週考三', 'score': 70},
#    {'name': '週考四', 'score': 45},
#    {'name': '期末考', 'score': 42}],
#   'name': 'b63033b14c5edb41b8fb97f34176b2c3',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107202506'},
#  {'_id': ObjectId('5ba65fa698d846d7943d701c'),
#   'bonusGrade': '4',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 75},
#    {'name': '週考三', 'score': 40},
#    {'name': '週考四', 'score': 35},
#    {'name': '期末考', 'score': 98}],
#   'name': '750f0843afd21085f07d99b55cbbf99d',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': '107203520'},
#  {'_id': ObjectId('5ba65fa698d846d7943d701d'),
#   'bonusGrade': '8',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 73},
#    {'name': '週考三', 'score': 65},
#    {'name': '週考四', 'score': 51},
#    {'name': '期末考', 'score': 86}],
#   'name': 'b32df509d9836e401c8bf719bcc77888',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107206504'},
#  {'_id': ObjectId('5ba65fa698d846d7943d701e'),
#   'bonusGrade': '8.75',
#   'grades': [{'name': '週考一', 'score': 79},
#    {'name': '週考二', 'score': 70},
#    {'name': '週考三', 'score': 74},
#    {'name': '週考四', 'score': 84},
#    {'name': '期末考', 'score': 88}],
#   'name': '0e89d96d20800de14eccfac2bbf4bbc1',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107206506'},
#  {'_id': ObjectId('5ba65fa698d846d7943d701f'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 83},
#    {'name': '週考三', 'score': 75},
#    {'name': '週考四', 'score': 78},
#    {'name': '期末考', 'score': 106}],
#   'name': '8f9e39c40e93adb32de70bac88baaa32',
#   'rollCallGrade': '9',
#   'stageGrade': '5',
#   'studentId': '107206528'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7020'),
#   'bonusGrade': '9.5',
#   'grades': [{'name': '週考一', 'score': 69},
#    {'name': '週考二', 'score': 92},
#    {'name': '週考三', 'score': 80},
#    {'name': '週考四', 'score': 94},
#    {'name': '期末考', 'score': 67}],
#   'name': '9149aff6b4187223531f85d48568524d',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107206530'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7021'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 85},
#    {'name': '週考三', 'score': 86},
#    {'name': '週考四', 'score': 84},
#    {'name': '期末考', 'score': 99}],
#   'name': '973367d16eb96a2e8e02fba085e9670b',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107208501'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7022'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 21},
#    {'name': '週考二', 'score': 20},
#    {'name': '週考三', 'score': 16},
#    {'name': '週考四', 'score': 13},
#    {'name': '期末考', 'score': 7}],
#   'name': '24f23f32596be1d7067050841765a506',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107206514'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7023'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 82},
#    {'name': '週考三', 'score': 68},
#    {'name': '週考四', 'score': 67},
#    {'name': '期末考', 'score': 74}],
#   'name': 'd877aabde13540cde30fb815fde88d86',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107206519'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7024'),
#   'bonusGrade': '1.5',
#   'grades': [{'name': '週考一', 'score': 68},
#    {'name': '週考二', 'score': 8},
#    {'name': '週考三', 'score': 26},
#    {'name': '週考四', 'score': 44},
#    {'name': '期末考', 'score': 35}],
#   'name': 'e9ec950de93c3526a518c75be34f78d4',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107208505'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7025'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 70},
#    {'name': '週考二', 'score': 68},
#    {'name': '週考三', 'score': 74},
#    {'name': '週考四', 'score': 63},
#    {'name': '期末考', 'score': 67}],
#   'name': '5ee667680feb005bc9dd490fd3ae40ec',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107208509'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7026'),
#   'bonusGrade': '4',
#   'grades': [{'name': '週考一', 'score': 63},
#    {'name': '週考二', 'score': 45},
#    {'name': '週考三', 'score': 36},
#    {'name': '週考四', 'score': 60},
#    {'name': '期末考', 'score': 91}],
#   'name': 'aa4987c0cfe1ead4e84b097ab0cc0810',
#   'rollCallGrade': '10',
#   'stageGrade': '7',
#   'studentId': '107302508'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7027'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 73},
#    {'name': '週考二', 'score': 95},
#    {'name': '週考三', 'score': 84},
#    {'name': '週考四', 'score': 86},
#    {'name': '期末考', 'score': 77}],
#   'name': 'eb256133a3958328156993be41a93c81',
#   'rollCallGrade': '9',
#   'stageGrade': '3',
#   'studentId': '107206507'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7028'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 94},
#    {'name': '週考三', 'score': 76},
#    {'name': '週考四', 'score': 71},
#    {'name': '期末考', 'score': 54}],
#   'name': '845321e96824258c7061f61f3c5ec3f4',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107302517'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7029'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 62},
#    {'name': '週考二', 'score': 43},
#    {'name': '週考三', 'score': 82},
#    {'name': '週考四', 'score': 33},
#    {'name': '期末考', 'score': 0}],
#   'name': '19f37696782eba4eff0d033ea7c1cc9f',
#   'rollCallGrade': '6',
#   'stageGrade': '2',
#   'studentId': '107302520'},
#  {'_id': ObjectId('5ba65fa698d846d7943d702a'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 98},
#    {'name': '週考二', 'score': 95},
#    {'name': '週考三', 'score': 83},
#    {'name': '週考四', 'score': 53},
#    {'name': '期末考', 'score': 98}],
#   'name': 'c56c8f27663e8cbefc2b0f61e45cec2d',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107302525'},
#  {'_id': ObjectId('5ba65fa698d846d7943d702b'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 92},
#    {'name': '週考二', 'score': 55},
#    {'name': '週考三', 'score': 66},
#    {'name': '週考四', 'score': 73},
#    {'name': '期末考', 'score': 101}],
#   'name': '0ef87c3f389332bcf9e4762821306a5b',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107302526'},
#  {'_id': ObjectId('5ba65fa698d846d7943d702c'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 73},
#    {'name': '週考三', 'score': 51},
#    {'name': '週考四', 'score': 92},
#    {'name': '期末考', 'score': 113}],
#   'name': '171e97d67ee89b1173f0a12defc088a2',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107302541'},
#  {'_id': ObjectId('5ba65fa698d846d7943d702d'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 23},
#    {'name': '週考三', 'score': 27},
#    {'name': '週考四', 'score': 14},
#    {'name': '期末考', 'score': 58}],
#   'name': '2cdb60cf260cc43cee0870d6e4f426e8',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': '107302554'},
#  {'_id': ObjectId('5ba65fa698d846d7943d702e'),
#   'bonusGrade': '11.5',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 47},
#    {'name': '週考三', 'score': 87},
#    {'name': '週考四', 'score': 68},
#    {'name': '期末考', 'score': 77}],
#   'name': 'ae866295f95324fdaae1d09dd5a5c573',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': '107302533'},
#  {'_id': ObjectId('5ba65fa698d846d7943d702f'),
#   'bonusGrade': '6.5',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 71},
#    {'name': '週考三', 'score': 82},
#    {'name': '週考四', 'score': 84},
#    {'name': '期末考', 'score': 86}],
#   'name': 'f1426decf7a881858562711f3b0644c7',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107303507'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7030'),
#   'bonusGrade': '3.5',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 56},
#    {'name': '週考三', 'score': 61},
#    {'name': '週考四', 'score': 77},
#    {'name': '期末考', 'score': 100}],
#   'name': '5b0ee9a8f13e354253bf4716830d6cb7',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107303510'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7031'),
#   'bonusGrade': '9.5',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 100},
#    {'name': '週考三', 'score': 64},
#    {'name': '週考四', 'score': 91},
#    {'name': '期末考', 'score': 94}],
#   'name': '0dedcdb0801b3d2a3448452c30a1a568',
#   'rollCallGrade': '10',
#   'stageGrade': '1',
#   'studentId': '107303511'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7032'),
#   'bonusGrade': '5.5',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 48},
#    {'name': '週考三', 'score': 84},
#    {'name': '週考四', 'score': 66},
#    {'name': '期末考', 'score': 98}],
#   'name': 'b8702d2a086dc5a4f7d5a10f4d2336b5',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107303514'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7033'),
#   'bonusGrade': '5.5',
#   'grades': [{'name': '週考一', 'score': 76},
#    {'name': '週考二', 'score': 50},
#    {'name': '週考三', 'score': 91},
#    {'name': '週考四', 'score': 76},
#    {'name': '期末考', 'score': 80}],
#   'name': 'b7bf9fdcf03f634574ff5d3abe03bd87',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107302531'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7034'),
#   'bonusGrade': '3.5',
#   'grades': [{'name': '週考一', 'score': 79},
#    {'name': '週考二', 'score': 67},
#    {'name': '週考三', 'score': 63},
#    {'name': '週考四', 'score': 68},
#    {'name': '期末考', 'score': 64}],
#   'name': '3b3695575b66e254ed09a05648b0cc11',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107302535'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7035'),
#   'bonusGrade': '5.5',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 53},
#    {'name': '週考三', 'score': 76},
#    {'name': '週考四', 'score': 44},
#    {'name': '期末考', 'score': 54}],
#   'name': '384006c97d45b7053ad01e55de5df987',
#   'rollCallGrade': '9',
#   'stageGrade': '1',
#   'studentId': '107303520'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7036'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 74},
#    {'name': '週考二', 'score': 58},
#    {'name': '週考三', 'score': 70},
#    {'name': '週考四', 'score': 66},
#    {'name': '期末考', 'score': 73}],
#   'name': 'c61903ef92d49604b58b52da8ff4ea2a',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107303521'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7037'),
#   'bonusGrade': '5',
#   'grades': [{'name': '週考一', 'score': 77},
#    {'name': '週考二', 'score': 62},
#    {'name': '週考三', 'score': 47},
#    {'name': '週考四', 'score': 52},
#    {'name': '期末考', 'score': 72}],
#   'name': '3823a58ae51e0977346b5ffa1d6bfad2',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107303522'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7038'),
#   'bonusGrade': '5.5',
#   'grades': [{'name': '週考一', 'score': 67},
#    {'name': '週考二', 'score': 74},
#    {'name': '週考三', 'score': 72},
#    {'name': '週考四', 'score': 77},
#    {'name': '期末考', 'score': 95}],
#   'name': '7681c65e96b437e00e724a364513635e',
#   'rollCallGrade': '11',
#   'stageGrade': '7',
#   'studentId': '107303542'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7039'),
#   'bonusGrade': '2.5',
#   'grades': [{'name': '週考一', 'score': 69},
#    {'name': '週考二', 'score': 87},
#    {'name': '週考三', 'score': 66},
#    {'name': '週考四', 'score': 80},
#    {'name': '期末考', 'score': 64}],
#   'name': '14c25e737415518f46881175477b2b71',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107303543'},
#  {'_id': ObjectId('5ba65fa698d846d7943d703a'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 87},
#    {'name': '週考二', 'score': 80},
#    {'name': '週考三', 'score': 74},
#    {'name': '週考四', 'score': 74},
#    {'name': '期末考', 'score': 90}],
#   'name': 'e2fa836cb95737fa0e5ba2e307f8edd3',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107303537'},
#  {'_id': ObjectId('5ba65fa698d846d7943d703b'),
#   'bonusGrade': '5.5',
#   'grades': [{'name': '週考一', 'score': 87},
#    {'name': '週考二', 'score': 91},
#    {'name': '週考三', 'score': 86},
#    {'name': '週考四', 'score': 68},
#    {'name': '期末考', 'score': 71}],
#   'name': 'af182d0a0556e59d218a4c51b71ab795',
#   'rollCallGrade': '10',
#   'stageGrade': '5',
#   'studentId': '107303525'},
#  {'_id': ObjectId('5ba65fa698d846d7943d703c'),
#   'bonusGrade': '3.75',
#   'grades': [{'name': '週考一', 'score': 52},
#    {'name': '週考二', 'score': 96},
#    {'name': '週考三', 'score': 81},
#    {'name': '週考四', 'score': 83},
#    {'name': '期末考', 'score': 83}],
#   'name': 'e00d6cf960408944fd398e7f9082fc67',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107303545'},
#  {'_id': ObjectId('5ba65fa698d846d7943d703d'),
#   'bonusGrade': '8',
#   'grades': [{'name': '週考一', 'score': 98},
#    {'name': '週考二', 'score': 92},
#    {'name': '週考三', 'score': 89},
#    {'name': '週考四', 'score': 91},
#    {'name': '期末考', 'score': 110}],
#   'name': '1e46fc3b7f33b61001dc3653bbfb60ed',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107303549'},
#  {'_id': ObjectId('5ba65fa698d846d7943d703e'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 79},
#    {'name': '週考二', 'score': 53},
#    {'name': '週考三', 'score': 65},
#    {'name': '週考四', 'score': 88},
#    {'name': '期末考', 'score': 87}],
#   'name': '978355a89a7a23a3304af3d384507e4b',
#   'rollCallGrade': '10',
#   'stageGrade': '1',
#   'studentId': '107303550'},
#  {'_id': ObjectId('5ba65fa698d846d7943d703f'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 45},
#    {'name': '週考三', 'score': 86},
#    {'name': '週考四', 'score': 62},
#    {'name': '期末考', 'score': 46}],
#   'name': 'f83ec29dbd02ab6d3fee76c1f2075d0b',
#   'rollCallGrade': '9',
#   'stageGrade': '0',
#   'studentId': '107303552'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7040'),
#   'bonusGrade': '5',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 24},
#    {'name': '週考三', 'score': 74},
#    {'name': '週考四', 'score': 35},
#    {'name': '期末考', 'score': 80}],
#   'name': '0365e2afd188034d9cdc4d92101943a3',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107303567'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7041'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 88},
#    {'name': '週考三', 'score': 67},
#    {'name': '週考四', 'score': 87},
#    {'name': '期末考', 'score': 101}],
#   'name': '1584c17c33a6ebfa4f53311c1b786967',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107303568'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7042'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 100},
#    {'name': '週考三', 'score': 79},
#    {'name': '週考四', 'score': 85},
#    {'name': '期末考', 'score': 102}],
#   'name': '38ff496212a29d4d1a4e60b7a9778504',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107303566'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7043'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 60},
#    {'name': '週考二', 'score': 28},
#    {'name': '週考三', 'score': 30},
#    {'name': '週考四', 'score': 22},
#    {'name': '期末考', 'score': 55}],
#   'name': '7deeb30b99b55b1c35382f3f7506b96a',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107303575'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7044'),
#   'bonusGrade': '4',
#   'grades': [{'name': '週考一', 'score': 77},
#    {'name': '週考二', 'score': 81},
#    {'name': '週考三', 'score': 59},
#    {'name': '週考四', 'score': 52},
#    {'name': '期末考', 'score': 51}],
#   'name': 'aa7f944100973702f6c82a40b98081e0',
#   'rollCallGrade': '9',
#   'stageGrade': '2',
#   'studentId': '107303576'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7045'),
#   'bonusGrade': '11',
#   'grades': [{'name': '週考一', 'score': 92},
#    {'name': '週考二', 'score': 80},
#    {'name': '週考三', 'score': 96},
#    {'name': '週考四', 'score': 100},
#    {'name': '期末考', 'score': 108}],
#   'name': '351895fb4c0f782fca547959a40ec018',
#   'rollCallGrade': '9',
#   'stageGrade': '4',
#   'studentId': '107303578'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7046'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 84},
#    {'name': '週考三', 'score': 64},
#    {'name': '週考四', 'score': 74},
#    {'name': '期末考', 'score': 66}],
#   'name': '52b8832a9ff6d99aa12bfd6221eeb37d',
#   'rollCallGrade': '9',
#   'stageGrade': '1',
#   'studentId': '107303572'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7047'),
#   'bonusGrade': '6.25',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 92},
#    {'name': '週考三', 'score': 75},
#    {'name': '週考四', 'score': 71},
#    {'name': '期末考', 'score': 70}],
#   'name': 'daafaf1580f833f352d8918cf5604607',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107303559'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7048'),
#   'bonusGrade': '2.5',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 66},
#    {'name': '週考三', 'score': 34},
#    {'name': '週考四', 'score': 70},
#    {'name': '期末考', 'score': 45}],
#   'name': '23d8a4e27b7fb6feda1b6d0c263acf5a',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107303588'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7049'),
#   'bonusGrade': '2',
#   'grades': [{'name': '週考一', 'score': 76},
#    {'name': '週考二', 'score': 65},
#    {'name': '週考三', 'score': 86},
#    {'name': '週考四', 'score': 51},
#    {'name': '期末考', 'score': 44}],
#   'name': '29e09c638c66d2a2bcf394ac06d9875f',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107303581'},
#  {'_id': ObjectId('5ba65fa698d846d7943d704a'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 96},
#    {'name': '週考三', 'score': 72},
#    {'name': '週考四', 'score': 90},
#    {'name': '期末考', 'score': 100}],
#   'name': '5eba9bbcf309320477621236d8cdcee2',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107303589'},
#  {'_id': ObjectId('5ba65fa698d846d7943d704b'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 68},
#    {'name': '週考三', 'score': 38},
#    {'name': '週考四', 'score': 37},
#    {'name': '期末考', 'score': 49}],
#   'name': 'b6380194ce5d97ec4a1957c4cb02ba48',
#   'rollCallGrade': '8',
#   'stageGrade': '4',
#   'studentId': '107303584'},
#  {'_id': ObjectId('5ba65fa698d846d7943d704c'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 82},
#    {'name': '週考三', 'score': 47},
#    {'name': '週考四', 'score': 0},
#    {'name': '期末考', 'score': 73}],
#   'name': '2fb5686048889810db3bf6e8f2d6d89e',
#   'rollCallGrade': '7',
#   'stageGrade': '2',
#   'studentId': '107304509'},
#  {'_id': ObjectId('5ba65fa698d846d7943d704d'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 100},
#    {'name': '週考二', 'score': 86},
#    {'name': '週考三', 'score': 85},
#    {'name': '週考四', 'score': 79},
#    {'name': '期末考', 'score': 93}],
#   'name': '16b57a4c78bb2fb588acf6822599c04e',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107304512'},
#  {'_id': ObjectId('5ba65fa698d846d7943d704e'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 66},
#    {'name': '週考二', 'score': 85},
#    {'name': '週考三', 'score': 0},
#    {'name': '週考四', 'score': 100},
#    {'name': '期末考', 'score': 70}],
#   'name': '0114a0371c7201c305157babe86e7536',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107304518'},
#  {'_id': ObjectId('5ba65fa698d846d7943d704f'),
#   'bonusGrade': '1.5',
#   'grades': [{'name': '週考一', 'score': 40},
#    {'name': '週考二', 'score': 30},
#    {'name': '週考三', 'score': 33},
#    {'name': '週考四', 'score': 58},
#    {'name': '期末考', 'score': 64}],
#   'name': 'aabdcaa84e3a12bf8c5c4aba15d6849e',
#   'rollCallGrade': '9',
#   'stageGrade': '2',
#   'studentId': '107304513'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7050'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 67},
#    {'name': '週考二', 'score': 87},
#    {'name': '週考三', 'score': 39},
#    {'name': '週考四', 'score': 64},
#    {'name': '期末考', 'score': 102}],
#   'name': '8dd811fe88af7fa03d06a4ad6c7f1cfa',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107304519'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7051'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 39},
#    {'name': '週考三', 'score': 44},
#    {'name': '週考四', 'score': 17},
#    {'name': '期末考', 'score': 22}],
#   'name': '7568c221c3438c4f902d939875b271e6',
#   'rollCallGrade': '1',
#   'stageGrade': '0',
#   'studentId': '107303532'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7052'),
#   'bonusGrade': '1',
#   'grades': [{'name': '週考一', 'score': 73},
#    {'name': '週考二', 'score': 14},
#    {'name': '週考三', 'score': 15},
#    {'name': '週考四', 'score': 14},
#    {'name': '期末考', 'score': 40}],
#   'name': '2953092302f9993fbd8644cdc14092f8',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': '107305506'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7053'),
#   'bonusGrade': '5.75',
#   'grades': [{'name': '週考一', 'score': 63},
#    {'name': '週考二', 'score': 49},
#    {'name': '週考三', 'score': 53},
#    {'name': '週考四', 'score': 75},
#    {'name': '期末考', 'score': 97}],
#   'name': '0139149c5222ffc1d8669d958fcf77f8',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107305512'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7054'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 77},
#    {'name': '週考二', 'score': 95},
#    {'name': '週考三', 'score': 87},
#    {'name': '週考四', 'score': 93},
#    {'name': '期末考', 'score': 101}],
#   'name': '793f168eda727982653d093894e7fb37',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107305504'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7055'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 79},
#    {'name': '週考二', 'score': 60},
#    {'name': '週考三', 'score': 64},
#    {'name': '週考四', 'score': 49},
#    {'name': '期末考', 'score': 47}],
#   'name': '5da92c7f155c800e9f8e06f1f1b0d49f',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107305515'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7056'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 43},
#    {'name': '週考二', 'score': 51},
#    {'name': '週考三', 'score': 32},
#    {'name': '週考四', 'score': 42},
#    {'name': '期末考', 'score': 25}],
#   'name': '28b56adde19ea3f8b60531917af9009b',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107305518'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7057'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 75},
#    {'name': '週考三', 'score': 75},
#    {'name': '週考四', 'score': 80},
#    {'name': '期末考', 'score': 66}],
#   'name': '4ed2fb526621b05fa29e3586592baef5',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107305501'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7058'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 70},
#    {'name': '週考三', 'score': 80},
#    {'name': '週考四', 'score': 83},
#    {'name': '期末考', 'score': 105}],
#   'name': '00a2ddc917162499aa732e1f3adc6c5c',
#   'rollCallGrade': '10',
#   'stageGrade': '6',
#   'studentId': '107501503'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7059'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 97},
#    {'name': '週考二', 'score': 95},
#    {'name': '週考三', 'score': 87},
#    {'name': '週考四', 'score': 100},
#    {'name': '期末考', 'score': 118}],
#   'name': '2f6fa57e8cb770cea58e1a83e0dcaa6c',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107501505'},
#  {'_id': ObjectId('5ba65fa698d846d7943d705a'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 65},
#    {'name': '週考三', 'score': 96},
#    {'name': '週考四', 'score': 90},
#    {'name': '期末考', 'score': 116}],
#   'name': '7cabdad08a4ff267effea59b82de689f',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107501506'},
#  {'_id': ObjectId('5ba65fa698d846d7943d705b'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 93},
#    {'name': '週考二', 'score': 82},
#    {'name': '週考三', 'score': 68},
#    {'name': '週考四', 'score': 88},
#    {'name': '期末考', 'score': 63}],
#   'name': 'b250ec8989063e43ec838e906797a44e',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107501510'},
#  {'_id': ObjectId('5ba65fa698d846d7943d705c'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 87},
#    {'name': '週考二', 'score': 71},
#    {'name': '週考三', 'score': 73},
#    {'name': '週考四', 'score': 45},
#    {'name': '期末考', 'score': 103}],
#   'name': '73fd62c089b61b7331f88b1f7da13951',
#   'rollCallGrade': '11',
#   'stageGrade': '6',
#   'studentId': '107501501'},
#  {'_id': ObjectId('5ba65fa698d846d7943d705d'),
#   'bonusGrade': '3.5',
#   'grades': [{'name': '週考一', 'score': 89},
#    {'name': '週考二', 'score': 65},
#    {'name': '週考三', 'score': 66},
#    {'name': '週考四', 'score': 93},
#    {'name': '期末考', 'score': 73}],
#   'name': '3b146e3563c30d2aed32294b47b1a712',
#   'rollCallGrade': '10',
#   'stageGrade': '5',
#   'studentId': '107305510'},
#  {'_id': ObjectId('5ba65fa698d846d7943d705e'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 30},
#    {'name': '週考三', 'score': 16},
#    {'name': '週考四', 'score': 46},
#    {'name': '期末考', 'score': 32}],
#   'name': '2a3e2d0d436d31283b669657149fd514',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107501520'},
#  {'_id': ObjectId('5ba65fa698d846d7943d705f'),
#   'bonusGrade': '5.5',
#   'grades': [{'name': '週考一', 'score': 70},
#    {'name': '週考二', 'score': 76},
#    {'name': '週考三', 'score': 66},
#    {'name': '週考四', 'score': 45},
#    {'name': '期末考', 'score': 96}],
#   'name': 'cd3e88c422ff71f204898551b8742481',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107501523'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7060'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 70},
#    {'name': '週考二', 'score': 84},
#    {'name': '週考三', 'score': 74},
#    {'name': '週考四', 'score': 82},
#    {'name': '期末考', 'score': 108}],
#   'name': '4a42682b7ea8d643f507889440a6747f',
#   'rollCallGrade': '11',
#   'stageGrade': '9',
#   'studentId': '107501540'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7061'),
#   'bonusGrade': '9.25',
#   'grades': [{'name': '週考一', 'score': 82},
#    {'name': '週考二', 'score': 66},
#    {'name': '週考三', 'score': 79},
#    {'name': '週考四', 'score': 42},
#    {'name': '期末考', 'score': 102}],
#   'name': '85dc2eb97a5f067018085c70283f23f7',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107501563'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7062'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 46},
#    {'name': '週考三', 'score': 53},
#    {'name': '週考四', 'score': 62},
#    {'name': '期末考', 'score': 76}],
#   'name': 'd2e5d200f25f18768b49ab904abe28db',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107501549'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7063'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 73},
#    {'name': '週考二', 'score': 92},
#    {'name': '週考三', 'score': 95},
#    {'name': '週考四', 'score': 70},
#    {'name': '期末考', 'score': 71}],
#   'name': 'b29889b10ff254ef0e5472d1a4d941df',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107501567'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7064'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 65},
#    {'name': '週考二', 'score': 85},
#    {'name': '週考三', 'score': 64},
#    {'name': '週考四', 'score': 78},
#    {'name': '期末考', 'score': 46}],
#   'name': '6f72177219191daf26c405efb1500ca8',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107501568'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7065'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 79},
#    {'name': '週考三', 'score': 88},
#    {'name': '週考四', 'score': 100},
#    {'name': '期末考', 'score': 115}],
#   'name': '867d40d20217ce9ab99b423bfbd14edc',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107502502'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7066'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 85},
#    {'name': '週考三', 'score': 87},
#    {'name': '週考四', 'score': 72},
#    {'name': '期末考', 'score': 90}],
#   'name': 'ec998d26442d98cffbde8feb4c15c55f',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107502503'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7067'),
#   'bonusGrade': '8',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 68},
#    {'name': '週考三', 'score': 51},
#    {'name': '週考四', 'score': 55},
#    {'name': '期末考', 'score': 85}],
#   'name': 'cbf29318f1a3643ea997569ef58f49b1',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107502506'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7068'),
#   'bonusGrade': '1.5',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 71},
#    {'name': '週考三', 'score': 58},
#    {'name': '週考四', 'score': 45},
#    {'name': '期末考', 'score': 99}],
#   'name': '3b51ea0be1c8c50d45f9eefd770ba28a',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107305521'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7069'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 84},
#    {'name': '週考三', 'score': 94},
#    {'name': '週考四', 'score': 83},
#    {'name': '期末考', 'score': 114}],
#   'name': '1fb4c7ed87a220c5b4e78d234cf19b1e',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107502507'},
#  {'_id': ObjectId('5ba65fa698d846d7943d706a'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 82},
#    {'name': '週考三', 'score': 93},
#    {'name': '週考四', 'score': 77},
#    {'name': '期末考', 'score': 62}],
#   'name': 'da2a08bebcba8eea5495c64870033181',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107502521'},
#  {'_id': ObjectId('5ba65fa698d846d7943d706b'),
#   'bonusGrade': '10',
#   'grades': [{'name': '週考一', 'score': 93},
#    {'name': '週考二', 'score': 91},
#    {'name': '週考三', 'score': 95},
#    {'name': '週考四', 'score': 90},
#    {'name': '期末考', 'score': 88}],
#   'name': '37fa0a19476095d5c8f4d2e882707380',
#   'rollCallGrade': '11',
#   'stageGrade': '6',
#   'studentId': '107502567'},
#  {'_id': ObjectId('5ba65fa698d846d7943d706c'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 58},
#    {'name': '週考二', 'score': 32},
#    {'name': '週考三', 'score': 33},
#    {'name': '週考四', 'score': 83},
#    {'name': '期末考', 'score': 45}],
#   'name': 'fe8142d1abbb127dd61cc033123c8ba5',
#   'rollCallGrade': '10',
#   'stageGrade': '4',
#   'studentId': '107502551'},
#  {'_id': ObjectId('5ba65fa698d846d7943d706d'),
#   'bonusGrade': '9.5',
#   'grades': [{'name': '週考一', 'score': 56},
#    {'name': '週考二', 'score': 84},
#    {'name': '週考三', 'score': 81},
#    {'name': '週考四', 'score': 87},
#    {'name': '期末考', 'score': 69}],
#   'name': 'ed86ced77f6faaa5706c30bf7c126e36',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107502540'},
#  {'_id': ObjectId('5ba65fa698d846d7943d706e'),
#   'bonusGrade': '5',
#   'grades': [{'name': '週考一', 'score': 94},
#    {'name': '週考二', 'score': 53},
#    {'name': '週考三', 'score': 48},
#    {'name': '週考四', 'score': 35},
#    {'name': '期末考', 'score': 44}],
#   'name': 'f0f7d79baaf0d67a0621c37964877b6a',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107502569'},
#  {'_id': ObjectId('5ba65fa698d846d7943d706f'),
#   'bonusGrade': '6.75',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 98},
#    {'name': '週考三', 'score': 65},
#    {'name': '週考四', 'score': 71},
#    {'name': '期末考', 'score': 33}],
#   'name': 'a45a137d9f046c3579a4fc62b33a3e8b',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107503512'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7070'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 98},
#    {'name': '週考二', 'score': 56},
#    {'name': '週考三', 'score': 89},
#    {'name': '週考四', 'score': 65},
#    {'name': '期末考', 'score': 90}],
#   'name': 'aa7f944100973702f6c82a40b98081e0',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107502574'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7071'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 70},
#    {'name': '週考二', 'score': 86},
#    {'name': '週考三', 'score': 80},
#    {'name': '週考四', 'score': 61},
#    {'name': '期末考', 'score': 86}],
#   'name': 'c7ecfc997553dcc2278373fed73959d7',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107503514'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7072'),
#   'bonusGrade': '6.5',
#   'grades': [{'name': '週考一', 'score': 39},
#    {'name': '週考二', 'score': 32},
#    {'name': '週考三', 'score': 30},
#    {'name': '週考四', 'score': 23},
#    {'name': '期末考', 'score': 45}],
#   'name': 'aa0f53cf2ea868e72ece91d9312b7bc1',
#   'rollCallGrade': '11',
#   'stageGrade': '2',
#   'studentId': '107502541'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7073'),
#   'bonusGrade': '5',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 70},
#    {'name': '週考三', 'score': 60},
#    {'name': '週考四', 'score': 82},
#    {'name': '期末考', 'score': 68}],
#   'name': '2e7cde71f345864fafb5176f9222f3ee',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': '107601516'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7074'),
#   'bonusGrade': '1',
#   'grades': [{'name': '週考一', 'score': 45},
#    {'name': '週考二', 'score': 11},
#    {'name': '週考三', 'score': 20},
#    {'name': '週考四', 'score': 1},
#    {'name': '期末考', 'score': 15}],
#   'name': 'acead24c1a0cde3c0e15a48289124c79',
#   'rollCallGrade': '8',
#   'stageGrade': '0',
#   'studentId': '107601521'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7075'),
#   'bonusGrade': '4.25',
#   'grades': [{'name': '週考一', 'score': 44},
#    {'name': '週考二', 'score': 73},
#    {'name': '週考三', 'score': 62},
#    {'name': '週考四', 'score': 77},
#    {'name': '期末考', 'score': 108}],
#   'name': 'fd37843b151e2bd1fe593d28911d8e56',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107601524'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7076'),
#   'bonusGrade': '5.75',
#   'grades': [{'name': '週考一', 'score': 55},
#    {'name': '週考二', 'score': 44},
#    {'name': '週考三', 'score': 52},
#    {'name': '週考四', 'score': 45},
#    {'name': '期末考', 'score': 43}],
#   'name': '3cc999347025d9801d60786658f2ce42',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107601525'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7077'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 86},
#    {'name': '週考二', 'score': 80},
#    {'name': '週考三', 'score': 72},
#    {'name': '週考四', 'score': 80},
#    {'name': '期末考', 'score': 85}],
#   'name': 'cdb0abe60b6f19c6baa485c8452ce64b',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107601532'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7078'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 89},
#    {'name': '週考三', 'score': 77},
#    {'name': '週考四', 'score': 87},
#    {'name': '期末考', 'score': 110}],
#   'name': 'b3da2bff6e10bf8ce27e01d29e1bc30b',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107504511'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7079'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 76},
#    {'name': '週考二', 'score': 62},
#    {'name': '週考三', 'score': 50},
#    {'name': '週考四', 'score': 85},
#    {'name': '期末考', 'score': 101}],
#   'name': '1123697e6cebdab3ff7612b49b05297b',
#   'rollCallGrade': '10',
#   'stageGrade': '9',
#   'studentId': '107601533'},
#  {'_id': ObjectId('5ba65fa698d846d7943d707a'),
#   'bonusGrade': '10.25',
#   'grades': [{'name': '週考一', 'score': 84},
#    {'name': '週考二', 'score': 54},
#    {'name': '週考三', 'score': 89},
#    {'name': '週考四', 'score': 53},
#    {'name': '期末考', 'score': 83}],
#   'name': '5451f31d28c1fcc75566c77661b8f1f9',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': '107601535'},
#  {'_id': ObjectId('5ba65fa698d846d7943d707b'),
#   'bonusGrade': '8.75',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 72},
#    {'name': '週考三', 'score': 65},
#    {'name': '週考四', 'score': 85},
#    {'name': '期末考', 'score': 100}],
#   'name': '01bff29787d8d00198b593238060ed34',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107601536'},
#  {'_id': ObjectId('5ba65fa698d846d7943d707c'),
#   'bonusGrade': '1.5',
#   'grades': [{'name': '週考一', 'score': 68},
#    {'name': '週考二', 'score': 10},
#    {'name': '週考三', 'score': 26},
#    {'name': '週考四', 'score': 4},
#    {'name': '期末考', 'score': 0}],
#   'name': 'fde648476f4a86efa5e160be24949508',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': '107601542'},
#  {'_id': ObjectId('5ba65fa698d846d7943d707d'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 81},
#    {'name': '週考三', 'score': 78},
#    {'name': '週考四', 'score': 94},
#    {'name': '期末考', 'score': 91}],
#   'name': 'fbffcfc2cbee66492b9d8834e1d48fcb',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107504505'},
#  {'_id': ObjectId('5ba65fa698d846d7943d707e'),
#   'bonusGrade': '7.75',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 82},
#    {'name': '週考三', 'score': 74},
#    {'name': '週考四', 'score': 83},
#    {'name': '期末考', 'score': 116}],
#   'name': 'b3232a6d3e77b84dce52e0369a90da38',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': '107602503'},
#  {'_id': ObjectId('5ba65fa698d846d7943d707f'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 79},
#    {'name': '週考二', 'score': 72},
#    {'name': '週考三', 'score': 77},
#    {'name': '週考四', 'score': 77},
#    {'name': '期末考', 'score': 98}],
#   'name': '752b73c050e4924e1b92db9f520508e0',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': '107602515'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7080'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 72},
#    {'name': '週考三', 'score': 68},
#    {'name': '週考四', 'score': 78},
#    {'name': '期末考', 'score': 90}],
#   'name': 'cb932b630d8221c67ff7064e15f2ece8',
#   'rollCallGrade': '5',
#   'stageGrade': '1',
#   'studentId': '107602526'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7081'),
#   'bonusGrade': '6.5',
#   'grades': [{'name': '週考一', 'score': 89},
#    {'name': '週考二', 'score': 55},
#    {'name': '週考三', 'score': 49},
#    {'name': '週考四', 'score': 88},
#    {'name': '期末考', 'score': 64}],
#   'name': 'c47d5ca3cfea0a68ce7d60c7c7ea9c78',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': '107602528'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7082'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 51},
#    {'name': '週考二', 'score': 30},
#    {'name': '週考三', 'score': 0},
#    {'name': '週考四', 'score': 0},
#    {'name': '期末考', 'score': 0}],
#   'name': '1c5f6a74fe441eb61f4ffd8ce9e551cd',
#   'rollCallGrade': '4',
#   'stageGrade': '0',
#   'studentId': '107602535'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7083'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 77},
#    {'name': '週考二', 'score': 13},
#    {'name': '週考三', 'score': 0},
#    {'name': '週考四', 'score': 0},
#    {'name': '期末考', 'score': 0}],
#   'name': '999f5b29797ac8e8cb64084a2a3ff93d',
#   'rollCallGrade': '3',
#   'stageGrade': '0',
#   'studentId': '107602536'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7084'),
#   'bonusGrade': '5',
#   'grades': [{'name': '週考一', 'score': 80},
#    {'name': '週考二', 'score': 33},
#    {'name': '週考三', 'score': 80},
#    {'name': '週考四', 'score': 82},
#    {'name': '期末考', 'score': 98}],
#   'name': '7179b164e4071db6aa0ed34339fed947',
#   'rollCallGrade': '10',
#   'stageGrade': '5',
#   'studentId': '107801507'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7085'),
#   'bonusGrade': '5.25',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 86},
#    {'name': '週考三', 'score': 73},
#    {'name': '週考四', 'score': 96},
#    {'name': '期末考', 'score': 70}],
#   'name': 'a95670f6135d0867585cf8c5f8295942',
#   'rollCallGrade': '10',
#   'stageGrade': '1',
#   'studentId': '107801513'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7086'),
#   'bonusGrade': '6.25',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 46},
#    {'name': '週考三', 'score': 76},
#    {'name': '週考四', 'score': 70},
#    {'name': '期末考', 'score': 73}],
#   'name': 'f67a617ac26fd9d6724cc40d76950560',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107802504'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7087'),
#   'bonusGrade': '5.75',
#   'grades': [{'name': '週考一', 'score': 77},
#    {'name': '週考二', 'score': 88},
#    {'name': '週考三', 'score': 81},
#    {'name': '週考四', 'score': 100},
#    {'name': '期末考', 'score': 92}],
#   'name': '100eb6a8fe4c982e6499da45be412241',
#   'rollCallGrade': '9',
#   'stageGrade': '0',
#   'studentId': '107802510'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7088'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 92},
#    {'name': '週考三', 'score': 94},
#    {'name': '週考四', 'score': 94},
#    {'name': '期末考', 'score': 107}],
#   'name': '2a95eb09a279c8ced540f1249fb4e5c2',
#   'rollCallGrade': '10',
#   'stageGrade': '6',
#   'studentId': '107802501'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7089'),
#   'bonusGrade': '4.75',
#   'grades': [{'name': '週考一', 'score': 46},
#    {'name': '週考二', 'score': 40},
#    {'name': '週考三', 'score': 85},
#    {'name': '週考四', 'score': 80},
#    {'name': '期末考', 'score': 53}],
#   'name': '57e9b55effe46ae7d7e42e6b84af44ee',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': '107802513'},
#  {'_id': ObjectId('5ba65fa698d846d7943d708a'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 51},
#    {'name': '週考三', 'score': 96},
#    {'name': '週考四', 'score': 88},
#    {'name': '期末考', 'score': 64}],
#   'name': '563d6bdbb9a285ac1a719fd9611105c2',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': '107802514'},
#  {'_id': ObjectId('5ba65fa698d846d7943d708b'),
#   'bonusGrade': '9.5',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 62},
#    {'name': '週考三', 'score': 73},
#    {'name': '週考四', 'score': 62},
#    {'name': '期末考', 'score': 32}],
#   'name': '9732237a4a28a1c849d060f6732497cc',
#   'rollCallGrade': '10',
#   'stageGrade': '1',
#   'studentId': '107802515'},
#  {'_id': ObjectId('5ba65fa698d846d7943d708c'),
#   'bonusGrade': '6.5',
#   'grades': [{'name': '週考一', 'score': 51},
#    {'name': '週考二', 'score': 36},
#    {'name': '週考三', 'score': 35},
#    {'name': '週考四', 'score': 30},
#    {'name': '期末考', 'score': 30}],
#   'name': '7e23c492a17a249f90c2fac0cc466f83',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': 'Y1070002'},
#  {'_id': ObjectId('5ba65fa698d846d7943d708d'),
#   'bonusGrade': '8.5',
#   'grades': [{'name': '週考一', 'score': 50},
#    {'name': '週考二', 'score': 32},
#    {'name': '週考三', 'score': 36},
#    {'name': '週考四', 'score': 56},
#    {'name': '期末考', 'score': 52}],
#   'name': '406247f5e67d5c4b2ba99278519b77ff',
#   'rollCallGrade': '10',
#   'stageGrade': '4',
#   'studentId': '107801516'},
#  {'_id': ObjectId('5ba65fa698d846d7943d708e'),
#   'bonusGrade': '9.5',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 76},
#    {'name': '週考三', 'score': 89},
#    {'name': '週考四', 'score': 60},
#    {'name': '期末考', 'score': 70}],
#   'name': 'e3420136216b16ce2e6fbef342377162',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': '107602523'},
#  {'_id': ObjectId('5ba65fa698d846d7943d708f'),
#   'bonusGrade': '5.75',
#   'grades': [{'name': '週考一', 'score': 76},
#    {'name': '週考二', 'score': 42},
#    {'name': '週考三', 'score': 79},
#    {'name': '週考四', 'score': 47},
#    {'name': '期末考', 'score': 63}],
#   'name': '2d8b8703165210782a6e08f09c4677d6',
#   'rollCallGrade': '11',
#   'stageGrade': '4',
#   'studentId': 'Y1070003'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7090'),
#   'bonusGrade': '7.5',
#   'grades': [{'name': '週考一', 'score': 76},
#    {'name': '週考二', 'score': 54},
#    {'name': '週考三', 'score': 22},
#    {'name': '週考四', 'score': 25},
#    {'name': '期末考', 'score': 84}],
#   'name': '36a195d0f2b5a0e0c74796965c53dbe8',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': 'Y1070006'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7091'),
#   'bonusGrade': '2.75',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 72},
#    {'name': '週考三', 'score': 50},
#    {'name': '週考四', 'score': 33},
#    {'name': '期末考', 'score': 68}],
#   'name': '1faf1756071a6cde1c571b7d3fc9ef24',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': 'Y1070004'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7092'),
#   'bonusGrade': '4.25',
#   'grades': [{'name': '週考一', 'score': 49},
#    {'name': '週考二', 'score': 23},
#    {'name': '週考三', 'score': 13},
#    {'name': '週考四', 'score': 37},
#    {'name': '期末考', 'score': 36}],
#   'name': 'f6126c51ba7bfde45f4eebcd09016814',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': 'Y1070009'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7093'),
#   'bonusGrade': '2.5',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 65},
#    {'name': '週考三', 'score': 40},
#    {'name': '週考四', 'score': 48},
#    {'name': '期末考', 'score': 69}],
#   'name': '8a8d80f9bed7d811da97c5842ca823b3',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': 'Y1070010'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7094'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 77},
#    {'name': '週考二', 'score': 14},
#    {'name': '週考三', 'score': 43},
#    {'name': '週考四', 'score': 19},
#    {'name': '期末考', 'score': 82}],
#   'name': 'd018e58c1c230cfb4843247b7624fd1b',
#   'rollCallGrade': '11',
#   'stageGrade': '1',
#   'studentId': 'Y1070007'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7095'),
#   'bonusGrade': '4.75',
#   'grades': [{'name': '週考一', 'score': 95},
#    {'name': '週考二', 'score': 0},
#    {'name': '週考三', 'score': 59},
#    {'name': '週考四', 'score': 64},
#    {'name': '期末考', 'score': 52}],
#   'name': '4c95735ae507e546b92089a9c5a40550',
#   'rollCallGrade': '11',
#   'stageGrade': '3',
#   'studentId': 'Y1070015'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7096'),
#   'bonusGrade': '9.5',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 87},
#    {'name': '週考三', 'score': 76},
#    {'name': '週考四', 'score': 76},
#    {'name': '期末考', 'score': 59}],
#   'name': '16735d32cc97e86637fc8ace80b9d35c',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': 'Y1070017'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7097'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 65},
#    {'name': '週考二', 'score': 5},
#    {'name': '週考三', 'score': 75},
#    {'name': '週考四', 'score': 63},
#    {'name': '期末考', 'score': 65}],
#   'name': 'd84cc43e6e28688ab645fb7ce86162b5',
#   'rollCallGrade': '10',
#   'stageGrade': '2',
#   'studentId': 'Y1070005'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7098'),
#   'bonusGrade': '7',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 93},
#    {'name': '週考三', 'score': 38},
#    {'name': '週考四', 'score': 78},
#    {'name': '期末考', 'score': 73}],
#   'name': 'ff384f83d8427b2b735b5b10591e3ac3',
#   'rollCallGrade': '9',
#   'stageGrade': '0',
#   'studentId': 'Y1070018'},
#  {'_id': ObjectId('5ba65fa698d846d7943d7099'),
#   'bonusGrade': '5.75',
#   'grades': [{'name': '週考一', 'score': 90},
#    {'name': '週考二', 'score': 65},
#    {'name': '週考三', 'score': 37},
#    {'name': '週考四', 'score': 55},
#    {'name': '期末考', 'score': 90}],
#   'name': 'f2ad1930d446b52fa899e638989e13d0',
#   'rollCallGrade': '11',
#   'stageGrade': '6',
#   'studentId': 'Y1070026'},
#  {'_id': ObjectId('5ba65fa698d846d7943d709a'),
#   'bonusGrade': '3',
#   'grades': [{'name': '週考一', 'score': 62},
#    {'name': '週考二', 'score': 10},
#    {'name': '週考三', 'score': 0},
#    {'name': '週考四', 'score': 0},
#    {'name': '期末考', 'score': 4}],
#   'name': '4ccef14e4f728d1ad1bf68fb44f2d0e6',
#   'rollCallGrade': '6',
#   'stageGrade': '0',
#   'studentId': 'Y1070028'},
#  {'_id': ObjectId('5ba65fa698d846d7943d709b'),
#   'bonusGrade': '9.75',
#   'grades': [{'name': '週考一', 'score': 72},
#    {'name': '週考二', 'score': 84},
#    {'name': '週考三', 'score': 82},
#    {'name': '週考四', 'score': 81},
#    {'name': '期末考', 'score': 76}],
#   'name': 'bb093fe4579d3baf1a12367e7e547ab1',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': 'Y1070025'},
#  {'_id': ObjectId('5ba65fa698d846d7943d709c'),
#   'bonusGrade': '2.5',
#   'grades': [{'name': '週考一', 'score': 82},
#    {'name': '週考二', 'score': 63},
#    {'name': '週考三', 'score': 57},
#    {'name': '週考四', 'score': 32},
#    {'name': '期末考', 'score': 74}],
#   'name': 'aea9e6db22c19a4d51d412b43c4189ce',
#   'rollCallGrade': '9',
#   'stageGrade': '0',
#   'studentId': 'Y1070019'},
#  {'_id': ObjectId('5ba65fa698d846d7943d709d'),
#   'bonusGrade': '1.25',
#   'grades': [{'name': '週考一', 'score': 84},
#    {'name': '週考二', 'score': 94},
#    {'name': '週考三', 'score': 65},
#    {'name': '週考四', 'score': 69},
#    {'name': '期末考', 'score': 102}],
#   'name': '58690e17e30f2eb179d4ed47435923df',
#   'rollCallGrade': '11',
#   'stageGrade': '5',
#   'studentId': 'Y1070037'},
#  {'_id': ObjectId('5ba65fa698d846d7943d709e'),
#   'bonusGrade': '0.5',
#   'grades': [{'name': '週考一', 'score': 75},
#    {'name': '週考二', 'score': 43},
#    {'name': '週考三', 'score': 16},
#    {'name': '週考四', 'score': 62},
#    {'name': '期末考', 'score': 26}],
#   'name': '7029466867268d63dd52d1367c9294e3',
#   'rollCallGrade': '8',
#   'stageGrade': '0',
#   'studentId': 'Y1070038'},
#  {'_id': ObjectId('5ba65fa698d846d7943d709f'),
#   'bonusGrade': '6.75',
#   'grades': [{'name': '週考一', 'score': 85},
#    {'name': '週考二', 'score': 100},
#    {'name': '週考三', 'score': 95},
#    {'name': '週考四', 'score': 87},
#    {'name': '期末考', 'score': 104}],
#   'name': '9205572256ecb17303ac5d7cc10a07e3',
#   'rollCallGrade': '11',
#   'stageGrade': '6',
#   'studentId': 'Y1070039'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a0'),
#   'bonusGrade': '0',
#   'grades': [{'name': '週考一', 'score': 22},
#    {'name': '週考二', 'score': 0},
#    {'name': '週考三', 'score': 0},
#    {'name': '週考四', 'score': 0},
#    {'name': '期末考', 'score': 0}],
#   'name': '57b92bfac28d04e8a0e5966b80d765e0',
#   'rollCallGrade': '1',
#   'stageGrade': '0',
#   'studentId': 'Y1070040'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a1'),
#   'bonusGrade': '10.75',
#   'grades': [{'name': '週考一', 'score': 78},
#    {'name': '週考二', 'score': 69},
#    {'name': '週考三', 'score': 61},
#    {'name': '週考四', 'score': 59},
#    {'name': '期末考', 'score': 75}],
#   'name': 'fbbefe33251d532f87f8704925b70126',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': 'Y1070042'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a2'),
#   'bonusGrade': '6.25',
#   'grades': [{'name': '週考一', 'score': 76},
#    {'name': '週考二', 'score': 19},
#    {'name': '週考三', 'score': 16},
#    {'name': '週考四', 'score': 38},
#    {'name': '期末考', 'score': 46}],
#   'name': '0dc053beb1379895e01825800548847a',
#   'rollCallGrade': '11',
#   'stageGrade': '0',
#   'studentId': 'Y1070021'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a3'),
#   'bonusGrade': '6',
#   'grades': [{'name': '週考一', 'score': 34},
#    {'name': '週考二', 'score': 62},
#    {'name': '週考三', 'score': 40},
#    {'name': '週考四', 'score': 62},
#    {'name': '期末考', 'score': 36}],
#   'name': '29183ec1e9eb4610d556301bf26ad585',
#   'rollCallGrade': '10',
#   'stageGrade': '0',
#   'studentId': 'Y1070052'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a4'),
#   'bonusGrade': '2',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 88},
#    {'name': '週考三', 'score': 61},
#    {'name': '週考四', 'score': 81},
#    {'name': '期末考', 'score': 76}],
#   'name': 'a7677524daf0c2a351d5485014debfcf',
#   'rollCallGrade': '10',
#   'stageGrade': '1',
#   'studentId': 'Y1070043'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a5'),
#   'bonusGrade': '3.5',
#   'grades': [{'name': '週考一', 'score': 83},
#    {'name': '週考二', 'score': 92},
#    {'name': '週考三', 'score': 35},
#    {'name': '週考四', 'score': 81},
#    {'name': '期末考', 'score': 30}],
#   'name': 'c320b9e58d0cd8bf17a92b027dd8ddb5',
#   'rollCallGrade': '8',
#   'stageGrade': '0',
#   'studentId': 'Y1070047'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a6'),
#   'bonusGrade': '8.25',
#   'grades': [{'name': '週考一', 'score': 81},
#    {'name': '週考二', 'score': 67},
#    {'name': '週考三', 'score': 89},
#    {'name': '週考四', 'score': 0},
#    {'name': '期末考', 'score': 87}],
#   'name': '919052341daa6e53a00c19fb74b1adfe',
#   'rollCallGrade': '10',
#   'stageGrade': '6',
#   'studentId': 'Y1070056'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a7'),
#   'bonusGrade': '0.5',
#   'grades': [{'name': '週考一', 'score': 65},
#    {'name': '週考二', 'score': 95},
#    {'name': '週考三', 'score': 88},
#    {'name': '週考四', 'score': 90},
#    {'name': '期末考', 'score': 98}],
#   'name': '9b1a0449d28f386ea926ff4055c8a15d',
#   'rollCallGrade': '11',
#   'stageGrade': '10',
#   'studentId': 'Y1070051'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a8'),
#   'bonusGrade': '12.5',
#   'grades': [{'name': '週考一', 'score': 44},
#    {'name': '週考二', 'score': 34},
#    {'name': '週考三', 'score': 55},
#    {'name': '週考四', 'score': 47},
#    {'name': '期末考', 'score': 25}],
#   'name': '40b21f2bc19b6eb932269ca6ed524db7',
#   'rollCallGrade': '9',
#   'stageGrade': '3',
#   'studentId': 'Y1070061'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70a9'),
#   'bonusGrade': '9',
#   'grades': [{'name': '週考一', 'score': 67},
#    {'name': '週考二', 'score': 60},
#    {'name': '週考三', 'score': 64},
#    {'name': '週考四', 'score': 37},
#    {'name': '期末考', 'score': 64}],
#   'name': '2859ecfa737e178c2bd0739871f3a16f',
#   'rollCallGrade': '10',
#   'stageGrade': '3',
#   'studentId': 'Y1070060'},
#  {'_id': ObjectId('5ba65fa698d846d7943d70aa'),
#   'bonusGrade': '4.5',
#   'grades': [{'name': '週考一', 'score': 88},
#    {'name': '週考二', 'score': 100},
#    {'name': '週考三', 'score': 94},
#    {'name': '週考四', 'score': 97},
#    {'name': '期末考', 'score': 86}],
#   'name': '9ec1c874c89beb16068838c81a03c1c1',
#   'rollCallGrade': '10',
#   'stageGrade': '6',
#   'studentId': 'Y1070070'}]

# %%
score_df = df['stageGrade']
score_df = score_df.dropna()
score_df = score_df.astype(float)
ncux_pre = score_df.astype(int)

# %% [markdown]
# # CYCU

# %% [markdown]
# ### CYCU_1031SP

# %%
db = conn['CYCU_1031SP']
collection = db['1031bSP2']
df = pd.DataFrame(list(collection.find()))
list(df)
# Out:
# ['MOOCs',
#  '_id',
#  '上課問答',
#  '加分小考',
#  '協作額外上機',
#  '原始總分',
#  '姓名',
#  '學號',
#  '小考一',
#  '小考二',
#  '最終成績',
#  '有完成遊戲',
#  '期中考',
#  '期末考',
#  '班級',
#  '程式一',
#  '程式三',
#  '程式二',
#  '線上成績',
#  '線上表現']

# %%
score_df = df['最終成績']
score_df = score_df.dropna()
score_df = score_df.astype(float)
cycu_1031sp = score_df.astype(int)

# %% [markdown]
# ### CYCU 1041SP

# %%
db = conn['CYCU_1041SP']
collection = db['1041aSP2']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#   MOOCs修課及格 Unnamed: 16 Unnamed: 17  Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0      None          學號          姓名          期中考         期末考         程式一
# 1      None          平均        None  44.43333333        33.2        None
# 2      None        None        None          30%         30%         10%
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  ...   小考一 小考二 最終成績 期中考 期末考  \
# 0         程式二         程式三       第一次小考       第二次小考  ...    52   0   28  55  15
# 1        None        None        None        None  ...    84   0   40  23  30
# 2         10%         10%          5%          5%  ...    52  83   80  63  55
#
#    程式一 程式三 程式二       線上成績   線上表現
# 0    0   0   0   1.836735  40.69
# 1   80   0   0  20.612245  77.89
# 2  103  92   0  43.061224  74.65
#
# [3 rows x 33 columns]

# %%
score_df = df['最終成績']
score_df = score_df.dropna()
score_df = score_df.astype(float)
cycu_1041sp = score_df.astype(int)

# %% [markdown]
# ### CYCU 1051SP

# %%
db = conn['CYCU_1051SP']
collection = db['1051aSP2']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id  上機  上課問答  上課題目   原始成績  \
# 0  5ba66ab498d846d794436d34  25    10  50.0  37.41
# 1  5ba66ab498d846d794436d35   0   100  21.0  40.84
# 2  5ba66ab498d846d794436d36  75     0   0.0  75.16
#
#                                  姓名        學號  小考一  小考二  最終成績  期中考  期末考  程式一  \
# 0  5054c77c1bdb639d856b7f69b50eb98b  10124341    0   32    40   30   25   95
# 1  bb38a73037a2b66ed2447892135dcc19  10227129   52   56    46   30   28    0
# 2  5621e2fd33b4a0f00186ab9e68085bd1  10227137   68   80    77   75   65   94
#
#    程式三  程式二  線上成績       線上表現
# 0    0    0  19.2  58.912917
# 1    0   54  14.0  58.195375
# 2    0    0  82.6  65.966333

# %%
score_df = df['最終成績']
score_df = score_df.dropna()
score_df = score_df.astype(float)
cycu_1051sp = score_df.astype(int)

# %% [markdown]
# ### CYCU 1042OS

# %%
db = conn['CYCU_1042OS']
collection = db['1042aOS2']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#   MOOCs修課及格                       _id  上機次數  上課問答   原始總分  \
# 0      None  5ba66ab098d846d7944301f9     2    20  48.65
# 1      None  5ba66ab098d846d7944301fa     2   100  56.10
# 2      None  5ba66ab098d846d7944301fb     2     0  51.75
#
#                                  姓名        學號  最終成績  期中考  期末考  第一支程式  第一次小考  \
# 0  87489bda6b4bd1373d774423d58cd4c4  10125134    67   30   20     98     72
# 1  fc8e80b9b11f98190c6af391238706c1  10220127    74   60   40     98     72
# 2  212cf45f5eabb72d948cc1d4165e1da7  10220140    67   53   28     95     76
#
#    第三支程式  第三次小考  第二支程式  第二次小考  第四次小考  線上成績   線上表現
# 0     70     72     88     89     36  76.6  81.26
# 1      0     58     89     76     36  44.6  71.76
# 2     28     34     74     79     48  60.0  87.62

# %%
score_df = df['最終成績']
score_df = score_df.dropna()
score_df = score_df.astype(float)
cycu_1042os = score_df.astype(int)

# %% [markdown]
# ### CYCU 1052OS

# %%
db = conn['CYCU_1052OS']
collection = db['1052bOS2']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id  上課問答   原始分數   原始總分  \
# 0  5ba66aba98d846d79443f3f9    10  14.79   5.50
# 1  5ba66aba98d846d79443f3fa    40  20.29   7.55
# 2  5ba66aba98d846d79443f3fb     0  61.26  46.05
#
#                                  姓名        學號  最終成績  期中考   期末考  第一支程式  第一次小考  \
# 0  6e04e4abf4a5d39ee5667cdb67093d15  10227228    15   10   0.0      0     50
# 1  456a1db66cd270383537f6b890fcb77f  10227106    20    3   8.0      0     40
# 2  d16f3be7c1dd6b93dd89097481a03daa  10227232    61   15  23.0     98     40
#
#    第三支程式  第三次小考  第二支程式  第二次小考  第五次小考  第四次小考  線上作業測驗       線上表現  課堂練習
# 0      0      0      0      0     52     56   10.00  56.704167  10.0
# 1      0     50      0     45     40      0    0.00  56.592361  72.2
# 2     98     43     98     65     28     44   40.61  78.784201  24.5

# %%
score_df = df['最終成績']
score_df = score_df.dropna()
score_df = score_df.astype(float)
cycu_1052os = score_df.astype(int)

# %% [markdown]
# # KU

# %% [markdown]
# ### KU BR01

# %%
db = conn['KU_dataset_1']
collection = db['data1_score.csv']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id  score userid
# 0  5ba2041898d846d794395461     80  ds101
# 1  5ba2041898d846d794395462     80  ds102
# 2  5ba2041898d846d794395463     60  ds103

# %%
score_df = df['score']
score_df = score_df.dropna()
score_df = score_df.astype(float)
ku_br01 = score_df.astype(int)

# %% [markdown]
# ### KU BR02

# %%
db = conn['KU_dataset_2']
collection = db['data2_score.csv']
df = pd.DataFrame(list(collection.find()))
df.head(3)
# Out:
#                         _id  score userid
# 0  5ba2041a98d846d79439e577  100.0  ds201
# 1  5ba2041a98d846d79439e578   62.5  ds202
# 2  5ba2041a98d846d79439e579   87.5  ds203

# %%
score_df = df['score']
score_df = score_df.dropna()
score_df = score_df.astype(float)
ku_br02 = score_df.astype(int)

# %% [markdown]
# # Visualization

# %%
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

# %%
xmin, xmax = 0, 100 
lnspc = np.linspace(xmin, xmax, 1000)

m, s = stats.norm.fit(ncux_fc)  
pdf_g_ncux_fc = stats.norm.pdf(lnspc, m, s) 
print(mean_confidence_interval(ncux_fc))
m, s = stats.norm.fit(ncux_chka)  
pdf_g_ncux_chka = stats.norm.pdf(lnspc, m, s) 
m, s = stats.norm.fit(ncux_chkb)  
pdf_g_ncux_chkb = stats.norm.pdf(lnspc, m, s) 
m, s = stats.norm.fit(ncux_pre)  
pdf_g_ncux_pre = stats.norm.pdf(lnspc, m, s) 

m, s = stats.norm.fit(cycu_1031sp)  
pdf_g_cycu_1031sp = stats.norm.pdf(lnspc, m, s)
m, s = stats.norm.fit(cycu_1041sp)  
pdf_g_cycu_1041sp = stats.norm.pdf(lnspc, m, s) 
m, s = stats.norm.fit(cycu_1051sp)  
pdf_g_cycu_1051sp = stats.norm.pdf(lnspc, m, s) 
m, s = stats.norm.fit(cycu_1042os)  
pdf_g_cycu_1042os = stats.norm.pdf(lnspc, m, s) 
m, s = stats.norm.fit(cycu_1052os)  
pdf_g_cycu_1052os = stats.norm.pdf(lnspc, m, s) 

m, s = stats.norm.fit(ku_br01)  
pdf_g_ku01 = stats.norm.pdf(lnspc, m, s) 
m, s = stats.norm.fit(ku_br02)  
pdf_g_ku02 = stats.norm.pdf(lnspc, m, s)
# Out:
# (64.59677419354838, 60.03849392973555, 69.15505445736122)

# %%
pdf_g_ncux_fc
# Out:
# array([3.10367750e-05, 3.16758968e-05, 3.23271577e-05, 3.29907658e-05,
#        3.36669321e-05, 3.43558708e-05, 3.50577992e-05, 3.57729381e-05,
#        3.65015111e-05, 3.72437453e-05, 3.79998711e-05, 3.87701223e-05,
#        3.95547360e-05, 4.03539528e-05, 4.11680166e-05, 4.19971751e-05,
#        4.28416792e-05, 4.37017836e-05, 4.45777466e-05, 4.54698302e-05,
#        4.63783000e-05, 4.73034253e-05, 4.82454793e-05, 4.92047391e-05,
#        5.01814854e-05, 5.11760030e-05, 5.21885807e-05, 5.32195110e-05,
#        5.42690908e-05, 5.53376209e-05, 5.64254060e-05, 5.75327554e-05,
#        5.86599821e-05, 5.98074038e-05, 6.09753422e-05, 6.21641234e-05,
#        6.33740779e-05, 6.46055405e-05, 6.58588506e-05, 6.71343519e-05,
#        6.84323930e-05, 6.97533266e-05, 7.10975104e-05, 7.24653067e-05,
#        7.38570823e-05, 7.52732090e-05, 7.67140634e-05, 7.81800267e-05,
#        7.96714853e-05, 8.11888303e-05, 8.27324579e-05, 8.43027693e-05,
#        8.59001707e-05, 8.75250736e-05, 8.91778943e-05, 9.08590548e-05,
#        9.25689818e-05, 9.43081078e-05, 9.60768702e-05, 9.78757120e-05,
#        9.97050816e-05, 1.01565433e-04, 1.03457225e-04, 1.05380924e-04,
#        1.07336998e-04, 1.09325926e-04, 1.11348188e-04, 1.13404272e-04,
#        1.15494671e-04, 1.17619885e-04, 1.19780418e-04, 1.21976783e-04,
#        1.24209494e-04, 1.26479076e-04, 1.28786057e-04, 1.31130972e-04,
#        1.33514362e-04, 1.35936775e-04, 1.38398764e-04, 1.40900889e-04,
#        1.43443715e-04, 1.46027816e-04, 1.48653769e-04, 1.51322160e-04,
#        1.54033581e-04, 1.56788629e-04, 1.59587909e-04, 1.62432032e-04,
#        1.65321617e-04, 1.68257287e-04, 1.71239673e-04, 1.74269414e-04,
#        1.77347154e-04, 1.80473544e-04, 1.83649243e-04, 1.86874916e-04,
#        1.90151234e-04, 1.93478878e-04, 1.96858532e-04, 2.00290890e-04,
#        2.03776651e-04, 2.07316524e-04, 2.10911222e-04, 2.14561466e-04,
#        2.18267986e-04, 2.22031516e-04, 2.25852800e-04, 2.29732589e-04,
#        2.33671640e-04, 2.37670717e-04, 2.41730594e-04, 2.45852049e-04,
#        2.50035871e-04, 2.54282853e-04, 2.58593798e-04, 2.62969515e-04,
#        2.67410821e-04, 2.71918541e-04, 2.76493507e-04, 2.81136558e-04,
#        2.85848543e-04, 2.90630315e-04, 2.95482739e-04, 3.00406683e-04,
#        3.05403025e-04, 3.10472652e-04, 3.15616457e-04, 3.20835341e-04,
#        3.26130213e-04, 3.31501988e-04, 3.36951592e-04, 3.42479957e-04,
#        3.48088022e-04, 3.53776735e-04, 3.59547051e-04, 3.65399935e-04,
#        3.71336355e-04, 3.77357293e-04, 3.83463734e-04, 3.89656672e-04,
#        3.95937110e-04, 4.02306059e-04, 4.08764535e-04, 4.15313564e-04,
#        4.21954181e-04, 4.28687425e-04, 4.35514347e-04, 4.42436003e-04,
#        4.49453458e-04, 4.56567783e-04, 4.63780059e-04, 4.71091374e-04,
#        4.78502823e-04, 4.86015509e-04, 4.93630543e-04, 5.01349043e-04,
#        5.09172136e-04, 5.17100954e-04, 5.25136640e-04, 5.33280342e-04,
#        5.41533216e-04, 5.49896427e-04, 5.58371144e-04, 5.66958547e-04,
#        5.75659821e-04, 5.84476161e-04, 5.93408766e-04, 6.02458844e-04,
#        6.11627612e-04, 6.20916289e-04, 6.30326107e-04, 6.39858302e-04,
#        6.49514116e-04, 6.59294801e-04, 6.69201614e-04, 6.79235819e-04,
#        6.89398687e-04, 6.99691496e-04, 7.10115531e-04, 7.20672082e-04,
#        7.31362446e-04, 7.42187929e-04, 7.53149841e-04, 7.64249498e-04,
#        7.75488225e-04, 7.86867349e-04, 7.98388207e-04, 8.10052139e-04,
#        8.21860495e-04, 8.33814626e-04, 8.45915892e-04, 8.58165658e-04,
#        8.70565294e-04, 8.83116176e-04, 8.95819685e-04, 9.08677208e-04,
#        9.21690137e-04, 9.34859869e-04, 9.48187806e-04, 9.61675354e-04,
#        9.75323925e-04, 9.89134936e-04, 1.00310981e-03, 1.01724996e-03,
#        1.03155684e-03, 1.04603186e-03, 1.06067647e-03, 1.07549211e-03,
#        1.09048022e-03, 1.10564226e-03, 1.12097967e-03, 1.13649392e-03,
#        1.15218647e-03, 1.16805877e-03, 1.18411229e-03, 1.20034850e-03,
#        1.21676888e-03, 1.23337489e-03, 1.25016802e-03, 1.26714974e-03,
#        1.28432153e-03, 1.30168488e-03, 1.31924127e-03, 1.33699219e-03,
#        1.35493912e-03, 1.37308355e-03, 1.39142698e-03, 1.40997089e-03,
#        1.42871678e-03, 1.44766613e-03, 1.46682045e-03, 1.48618122e-03,
#        1.50574994e-03, 1.52552810e-03, 1.54551719e-03, 1.56571870e-03,
#        1.58613413e-03, 1.60676497e-03, 1.62761270e-03, 1.64867881e-03,
#        1.66996479e-03, 1.69147212e-03, 1.71320229e-03, 1.73515677e-03,
#        1.75733705e-03, 1.77974459e-03, 1.80238087e-03, 1.82524736e-03,
#        1.84834553e-03, 1.87167683e-03, 1.89524273e-03, 1.91904468e-03,
#        1.94308413e-03, 1.96736253e-03, 1.99188131e-03, 2.01664191e-03,
#        2.04164578e-03, 2.06689432e-03, 2.09238896e-03, 2.11813111e-03,
#        2.14412219e-03, 2.17036359e-03, 2.19685670e-03, 2.22360292e-03,
#        2.25060362e-03, 2.27786019e-03, 2.30537397e-03, 2.33314633e-03,
#        2.36117863e-03, 2.38947219e-03, 2.41802835e-03, 2.44684843e-03,
#        2.47593375e-03, 2.50528560e-03, 2.53490529e-03, 2.56479409e-03,
#        2.59495328e-03, 2.62538411e-03, 2.65608784e-03, 2.68706571e-03,
#        2.71831894e-03, 2.74984876e-03, 2.78165636e-03, 2.81374293e-03,
#        2.84610965e-03, 2.87875769e-03, 2.91168820e-03, 2.94490231e-03,
#        2.97840115e-03, 3.01218582e-03, 3.04625743e-03, 3.08061705e-03,
#        3.11526574e-03, 3.15020456e-03, 3.18543453e-03, 3.22095668e-03,
#        3.25677200e-03, 3.29288147e-03, 3.32928607e-03, 3.36598673e-03,
#        3.40298440e-03, 3.44027997e-03, 3.47787436e-03, 3.51576843e-03,
#        3.55396304e-03, 3.59245902e-03, 3.63125720e-03, 3.67035837e-03,
#        3.70976331e-03, 3.74947278e-03, 3.78948751e-03, 3.82980821e-03,
#        3.87043559e-03, 3.91137030e-03, 3.95261301e-03, 3.99416433e-03,
#        4.03602486e-03, 4.07819520e-03, 4.12067590e-03, 4.16346748e-03,
#        4.20657047e-03, 4.24998533e-03, 4.29371255e-03, 4.33775254e-03,
#        4.38210571e-03, 4.42677247e-03, 4.47175315e-03, 4.51704809e-03,
#        4.56265760e-03, 4.60858196e-03, 4.65482141e-03, 4.70137618e-03,
#        4.74824647e-03, 4.79543244e-03, 4.84293424e-03, 4.89075196e-03,
#        4.93888570e-03, 4.98733551e-03, 5.03610141e-03, 5.08518339e-03,
#        5.13458141e-03, 5.18429541e-03, 5.23432529e-03, 5.28467091e-03,
#        5.33533212e-03, 5.38630872e-03, 5.43760050e-03, 5.48920718e-03,
#        5.54112849e-03, 5.59336409e-03, 5.64591365e-03, 5.69877676e-03,
#        5.75195300e-03, 5.80544192e-03, 5.85924304e-03, 5.91335582e-03,
#        5.96777971e-03, 6.02251411e-03, 6.07755840e-03, 6.13291191e-03,
#        6.18857395e-03, 6.24454377e-03, 6.30082062e-03, 6.35740367e-03,
#        6.41429209e-03, 6.47148500e-03, 6.52898148e-03, 6.58678058e-03,
#        6.64488130e-03, 6.70328262e-03, 6.76198347e-03, 6.82098274e-03,
#        6.88027930e-03, 6.93987196e-03, 6.99975950e-03, 7.05994067e-03,
#        7.12041417e-03, 7.18117867e-03, 7.24223278e-03, 7.30357510e-03,
#        7.36520417e-03, 7.42711850e-03, 7.48931655e-03, 7.55179676e-03,
#        7.61455751e-03, 7.67759715e-03, 7.74091399e-03, 7.80450628e-03,
#        7.86837226e-03, 7.93251012e-03, 7.99691799e-03, 8.06159399e-03,
#        8.12653617e-03, 8.19174256e-03, 8.25721114e-03, 8.32293985e-03,
#        8.38892658e-03, 8.45516920e-03, 8.52166552e-03, 8.58841332e-03,
#        8.65541032e-03, 8.72265422e-03, 8.79014268e-03, 8.85787330e-03,
#        8.92584364e-03, 8.99405124e-03, 9.06249358e-03, 9.13116809e-03,
#        9.20007219e-03, 9.26920324e-03, 9.33855854e-03, 9.40813538e-03,
#        9.47793099e-03, 9.54794258e-03, 9.61816728e-03, 9.68860221e-03,
#        9.75924444e-03, 9.83009101e-03, 9.90113889e-03, 9.97238505e-03,
#        1.00438264e-02, 1.01154597e-02, 1.01872820e-02, 1.02592898e-02,
#        1.03314801e-02, 1.04038495e-02, 1.04763946e-02, 1.05491121e-02,
#        1.06219985e-02, 1.06950505e-02, 1.07682645e-02, 1.08416369e-02,
#        1.09151643e-02, 1.09888429e-02, 1.10626692e-02, 1.11366394e-02,
#        1.12107499e-02, 1.12849968e-02, 1.13593763e-02, 1.14338846e-02,
#        1.15085179e-02, 1.15832721e-02, 1.16581434e-02, 1.17331277e-02,
#        1.18082211e-02, 1.18834194e-02, 1.19587186e-02, 1.20341145e-02,
#        1.21096029e-02, 1.21851797e-02, 1.22608406e-02, 1.23365813e-02,
#        1.24123975e-02, 1.24882849e-02, 1.25642391e-02, 1.26402557e-02,
#        1.27163302e-02, 1.27924582e-02, 1.28686351e-02, 1.29448564e-02,
#        1.30211176e-02, 1.30974141e-02, 1.31737411e-02, 1.32500942e-02,
#        1.33264684e-02, 1.34028593e-02, 1.34792619e-02, 1.35556715e-02,
#        1.36320834e-02, 1.37084926e-02, 1.37848944e-02, 1.38612838e-02,
#        1.39376560e-02, 1.40140059e-02, 1.40903287e-02, 1.41666193e-02,
#        1.42428727e-02, 1.43190840e-02, 1.43952479e-02, 1.44713596e-02,
#        1.45474138e-02, 1.46234054e-02, 1.46993294e-02, 1.47751805e-02,
#        1.48509535e-02, 1.49266433e-02, 1.50022446e-02, 1.50777522e-02,
#        1.51531608e-02, 1.52284651e-02, 1.53036599e-02, 1.53787399e-02,
#        1.54536997e-02, 1.55285341e-02, 1.56032375e-02, 1.56778048e-02,
#        1.57522304e-02, 1.58265091e-02, 1.59006354e-02, 1.59746039e-02,
#        1.60484091e-02, 1.61220458e-02, 1.61955083e-02, 1.62687913e-02,
#        1.63418894e-02, 1.64147970e-02, 1.64875086e-02, 1.65600189e-02,
#        1.66323223e-02, 1.67044133e-02, 1.67762865e-02, 1.68479364e-02,
#        1.69193574e-02, 1.69905441e-02, 1.70614909e-02, 1.71321925e-02,
#        1.72026432e-02, 1.72728377e-02, 1.73427703e-02, 1.74124356e-02,
#        1.74818282e-02, 1.75509425e-02, 1.76197731e-02, 1.76883144e-02,
#        1.77565611e-02, 1.78245076e-02, 1.78921486e-02, 1.79594785e-02,
#        1.80264919e-02, 1.80931835e-02, 1.81595477e-02, 1.82255792e-02,
#        1.82912726e-02, 1.83566226e-02, 1.84216237e-02, 1.84862705e-02,
#        1.85505579e-02, 1.86144803e-02, 1.86780327e-02, 1.87412095e-02,
#        1.88040056e-02, 1.88664158e-02, 1.89284347e-02, 1.89900573e-02,
#        1.90512781e-02, 1.91120923e-02, 1.91724944e-02, 1.92324795e-02,
#        1.92920425e-02, 1.93511782e-02, 1.94098815e-02, 1.94681476e-02,
#        1.95259713e-02, 1.95833477e-02, 1.96402719e-02, 1.96967389e-02,
#        1.97527438e-02, 1.98082819e-02, 1.98633481e-02, 1.99179378e-02,
#        1.99720462e-02, 2.00256686e-02, 2.00788002e-02, 2.01314364e-02,
#        2.01835726e-02, 2.02352041e-02, 2.02863264e-02, 2.03369350e-02,
#        2.03870255e-02, 2.04365932e-02, 2.04856339e-02, 2.05341432e-02,
#        2.05821167e-02, 2.06295502e-02, 2.06764393e-02, 2.07227800e-02,
#        2.07685680e-02, 2.08137993e-02, 2.08584697e-02, 2.09025752e-02,
#        2.09461118e-02, 2.09890757e-02, 2.10314628e-02, 2.10732694e-02,
#        2.11144916e-02, 2.11551257e-02, 2.11951680e-02, 2.12346149e-02,
#        2.12734627e-02, 2.13117079e-02, 2.13493469e-02, 2.13863764e-02,
#        2.14227929e-02, 2.14585931e-02, 2.14937737e-02, 2.15283314e-02,
#        2.15622631e-02, 2.15955656e-02, 2.16282358e-02, 2.16602708e-02,
#        2.16916675e-02, 2.17224230e-02, 2.17525345e-02, 2.17819992e-02,
#        2.18108144e-02, 2.18389773e-02, 2.18664853e-02, 2.18933360e-02,
#        2.19195267e-02, 2.19450550e-02, 2.19699186e-02, 2.19941150e-02,
#        2.20176422e-02, 2.20404977e-02, 2.20626796e-02, 2.20841856e-02,
#        2.21050139e-02, 2.21251624e-02, 2.21446293e-02, 2.21634127e-02,
#        2.21815108e-02, 2.21989220e-02, 2.22156445e-02, 2.22316769e-02,
#        2.22470177e-02, 2.22616652e-02, 2.22756183e-02, 2.22888756e-02,
#        2.23014357e-02, 2.23132976e-02, 2.23244601e-02, 2.23349221e-02,
#        2.23446827e-02, 2.23537410e-02, 2.23620960e-02, 2.23697470e-02,
#        2.23766933e-02, 2.23829342e-02, 2.23884691e-02, 2.23932975e-02,
#        2.23974189e-02, 2.24008330e-02, 2.24035393e-02, 2.24055378e-02,
#        2.24068281e-02, 2.24074102e-02, 2.24072839e-02, 2.24064494e-02,
#        2.24049066e-02, 2.24026558e-02, 2.23996972e-02, 2.23960309e-02,
#        2.23916574e-02, 2.23865772e-02, 2.23807906e-02, 2.23742982e-02,
#        2.23671006e-02, 2.23591986e-02, 2.23505928e-02, 2.23412841e-02,
#        2.23312733e-02, 2.23205615e-02, 2.23091496e-02, 2.22970387e-02,
#        2.22842299e-02, 2.22707245e-02, 2.22565237e-02, 2.22416289e-02,
#        2.22260414e-02, 2.22097628e-02, 2.21927946e-02, 2.21751384e-02,
#        2.21567958e-02, 2.21377686e-02, 2.21180585e-02, 2.20976675e-02,
#        2.20765974e-02, 2.20548502e-02, 2.20324280e-02, 2.20093328e-02,
#        2.19855668e-02, 2.19611323e-02, 2.19360315e-02, 2.19102668e-02,
#        2.18838406e-02, 2.18567553e-02, 2.18290136e-02, 2.18006178e-02,
#        2.17715708e-02, 2.17418753e-02, 2.17115339e-02, 2.16805494e-02,
#        2.16489249e-02, 2.16166632e-02, 2.15837672e-02, 2.15502401e-02,
#        2.15160849e-02, 2.14813048e-02, 2.14459030e-02, 2.14098827e-02,
#        2.13732473e-02, 2.13360002e-02, 2.12981447e-02, 2.12596843e-02,
#        2.12206225e-02, 2.11809630e-02, 2.11407093e-02, 2.10998651e-02,
#        2.10584342e-02, 2.10164202e-02, 2.09738271e-02, 2.09306586e-02,
#        2.08869188e-02, 2.08426114e-02, 2.07977407e-02, 2.07523105e-02,
#        2.07063250e-02, 2.06597883e-02, 2.06127046e-02, 2.05650782e-02,
#        2.05169132e-02, 2.04682140e-02, 2.04189849e-02, 2.03692304e-02,
#        2.03189547e-02, 2.02681625e-02, 2.02168581e-02, 2.01650462e-02,
#        2.01127313e-02, 2.00599179e-02, 2.00066109e-02, 1.99528147e-02,
#        1.98985342e-02, 1.98437741e-02, 1.97885391e-02, 1.97328341e-02,
#        1.96766639e-02, 1.96200334e-02, 1.95629474e-02, 1.95054110e-02,
#        1.94474290e-02, 1.93890065e-02, 1.93301485e-02, 1.92708599e-02,
#        1.92111459e-02, 1.91510115e-02, 1.90904619e-02, 1.90295022e-02,
#        1.89681376e-02, 1.89063732e-02, 1.88442142e-02, 1.87816659e-02,
#        1.87187334e-02, 1.86554221e-02, 1.85917373e-02, 1.85276841e-02,
#        1.84632680e-02, 1.83984943e-02, 1.83333682e-02, 1.82678952e-02,
#        1.82020807e-02, 1.81359299e-02, 1.80694484e-02, 1.80026415e-02,
#        1.79355146e-02, 1.78680732e-02, 1.78003227e-02, 1.77322686e-02,
#        1.76639162e-02, 1.75952712e-02, 1.75263389e-02, 1.74571247e-02,
#        1.73876343e-02, 1.73178731e-02, 1.72478465e-02, 1.71775601e-02,
#        1.71070193e-02, 1.70362297e-02, 1.69651967e-02, 1.68939258e-02,
#        1.68224226e-02, 1.67506925e-02, 1.66787411e-02, 1.66065737e-02,
#        1.65341959e-02, 1.64616133e-02, 1.63888311e-02, 1.63158550e-02,
#        1.62426904e-02, 1.61693428e-02, 1.60958176e-02, 1.60221202e-02,
#        1.59482561e-02, 1.58742307e-02, 1.58000495e-02, 1.57257178e-02,
#        1.56512411e-02, 1.55766247e-02, 1.55018740e-02, 1.54269943e-02,
#        1.53519911e-02, 1.52768695e-02, 1.52016351e-02, 1.51262929e-02,
#        1.50508484e-02, 1.49753068e-02, 1.48996734e-02, 1.48239534e-02,
#        1.47481519e-02, 1.46722743e-02, 1.45963256e-02, 1.45203111e-02,
#        1.44442358e-02, 1.43681049e-02, 1.42919235e-02, 1.42156966e-02,
#        1.41394294e-02, 1.40631267e-02, 1.39867937e-02, 1.39104353e-02,
#        1.38340564e-02, 1.37576620e-02, 1.36812571e-02, 1.36048463e-02,
#        1.35284347e-02, 1.34520270e-02, 1.33756280e-02, 1.32992426e-02,
#        1.32228753e-02, 1.31465310e-02, 1.30702143e-02, 1.29939299e-02,
#        1.29176824e-02, 1.28414764e-02, 1.27653164e-02, 1.26892069e-02,
#        1.26131526e-02, 1.25371577e-02, 1.24612268e-02, 1.23853643e-02,
#        1.23095745e-02, 1.22338618e-02, 1.21582304e-02, 1.20826846e-02,
#        1.20072287e-02, 1.19318668e-02, 1.18566031e-02, 1.17814417e-02,
#        1.17063867e-02, 1.16314422e-02, 1.15566122e-02, 1.14819007e-02,
#        1.14073115e-02, 1.13328486e-02, 1.12585159e-02, 1.11843173e-02,
#        1.11102564e-02, 1.10363370e-02, 1.09625629e-02, 1.08889378e-02,
#        1.08154652e-02, 1.07421489e-02, 1.06689922e-02, 1.05959989e-02,
#        1.05231722e-02, 1.04505158e-02, 1.03780329e-02, 1.03057270e-02,
#        1.02336014e-02, 1.01616593e-02, 1.00899041e-02, 1.00183388e-02,
#        9.94696669e-03, 9.87579086e-03, 9.80481439e-03, 9.73404031e-03,
#        9.66347163e-03, 9.59311130e-03, 9.52296224e-03, 9.45302732e-03,
#        9.38330937e-03, 9.31381118e-03, 9.24453550e-03, 9.17548505e-03,
#        9.10666248e-03, 9.03807043e-03, 8.96971148e-03, 8.90158816e-03,
#        8.83370299e-03, 8.76605841e-03, 8.69865685e-03, 8.63150069e-03,
#        8.56459225e-03, 8.49793384e-03, 8.43152770e-03, 8.36537604e-03,
#        8.29948104e-03, 8.23384482e-03, 8.16846946e-03, 8.10335702e-03,
#        8.03850950e-03, 7.97392885e-03, 7.90961701e-03, 7.84557585e-03,
#        7.78180722e-03, 7.71831291e-03, 7.65509469e-03, 7.59215427e-03,
#        7.52949333e-03, 7.46711351e-03, 7.40501641e-03, 7.34320359e-03,
#        7.28167657e-03, 7.22043681e-03, 7.15948578e-03, 7.09882485e-03,
#        7.03845540e-03, 6.97837875e-03, 6.91859617e-03, 6.85910892e-03,
#        6.79991820e-03, 6.74102517e-03, 6.68243096e-03, 6.62413667e-03,
#        6.56614335e-03, 6.50845201e-03, 6.45106363e-03, 6.39397915e-03,
#        6.33719948e-03, 6.28072548e-03, 6.22455798e-03, 6.16869778e-03,
#        6.11314564e-03, 6.05790227e-03, 6.00296837e-03, 5.94834458e-03,
#        5.89403152e-03, 5.84002977e-03, 5.78633988e-03, 5.73296235e-03,
#        5.67989768e-03, 5.62714629e-03, 5.57470860e-03, 5.52258499e-03,
#        5.47077579e-03, 5.41928133e-03, 5.36810187e-03, 5.31723766e-03,
#        5.26668893e-03, 5.21645583e-03, 5.16653854e-03, 5.11693716e-03,
#        5.06765179e-03, 5.01868247e-03, 4.97002925e-03, 4.92169210e-03,
#        4.87367101e-03, 4.82596591e-03, 4.77857671e-03, 4.73150328e-03,
#        4.68474548e-03, 4.63830313e-03, 4.59217602e-03, 4.54636392e-03,
#        4.50086657e-03, 4.45568368e-03, 4.41081494e-03, 4.36626001e-03,
#        4.32201851e-03, 4.27809006e-03, 4.23447423e-03, 4.19117059e-03,
#        4.14817866e-03, 4.10549795e-03, 4.06312795e-03, 4.02106810e-03,
#        3.97931785e-03, 3.93787661e-03, 3.89674377e-03, 3.85591868e-03,
#        3.81540070e-03, 3.77518914e-03, 3.73528330e-03, 3.69568247e-03,
#        3.65638590e-03, 3.61739282e-03, 3.57870245e-03, 3.54031398e-03,
#        3.50222660e-03, 3.46443945e-03, 3.42695168e-03, 3.38976240e-03,
#        3.35287070e-03, 3.31627568e-03, 3.27997639e-03, 3.24397188e-03,
#        3.20826118e-03, 3.17284329e-03, 3.13771722e-03, 3.10288194e-03])

# %%
X = np.array([pdf_g_ncux_fc, 
              pdf_g_ncux_chka, 
              pdf_g_ncux_chkb, 
              #pdf_g_ncux_pre,
              pdf_g_cycu_1031sp,
              pdf_g_cycu_1041sp,
              pdf_g_cycu_1051sp,
              pdf_g_cycu_1042os,
              pdf_g_cycu_1052os,
              pdf_g_ku01, 
              pdf_g_ku02])
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_
labels
# Out:
# array([0, 2, 2, 0, 0, 0, 0, 0, 1, 1], dtype=int32)

# %%
ncux_fc_kurs = 'kurtosis=' + str(format(kurtosis(ncux_fc), '.2f'))
ncux_fc_skew = 'skew=' + str(format(skew(ncux_fc), '.2f'))
ncux_fc_type = 'type=' + str(labels[0])
ncux_chka_kurs = 'kurtosis=' + str(format(kurtosis(ncux_chka), '.2f'))
ncux_chka_skew = 'skew=' + str(format(skew(ncux_chka), '.2f'))
ncux_chka_type = 'type=' + str(labels[1])
ncux_chkb_kurs = 'kurtosis=' + str(format(kurtosis(ncux_chkb), '.2f'))
ncux_chkb_skew = 'skew=' + str(format(skew(ncux_chkb), '.2f'))
ncux_chkb_type = 'type=' + str(labels[2])

cycu_1031sp_kurs = 'kurtosis=' + str(format(kurtosis(cycu_1031sp), '.2f'))
cycu_1031sp_skew = 'skew=' + str(format(skew(cycu_1031sp), '.2f'))
cycu_1031sp_type = 'type=' + str(labels[3])
cycu_1041sp_kurs = 'kurtosis=' + str(format(kurtosis(cycu_1041sp), '.2f'))
cycu_1041sp_skew = 'skew=' + str(format(skew(cycu_1041sp), '.2f'))
cycu_1041sp_type = 'type=' + str(labels[4])
cycu_1051sp_kurs = 'kurtosis=' + str(format(kurtosis(cycu_1051sp), '.2f'))
cycu_1051sp_skew = 'skew=' + str(format(skew(cycu_1051sp), '.2f'))
cycu_1051sp_type = 'type=' + str(labels[5])

cycu_1042os_kurs = 'kurtosis=' + str(format(kurtosis(cycu_1052os), '.2f'))
cycu_1042os_skew = 'skew=' + str(format(skew(cycu_1042os), '.2f'))
cycu_1042os_type = 'type=' + str(labels[6])
cycu_1052os_kurs = 'kurtosis=' + str(format(kurtosis(cycu_1052os), '.2f'))
cycu_1052os_skew = 'skew=' + str(format(skew(cycu_1042os), '.2f'))
cycu_1052os_type = 'type=' + str(labels[7])


ku_br01_kurs = 'kurtosis=' + str(format(kurtosis(ku_br01), '.2f'))
ku_br01_skew = 'skew=' + str(format(skew(ku_br01), '.2f'))
ku_br01_type = 'type=' + str(labels[8])
ku_br02_kurs = 'kurtosis=' + str(format(kurtosis(ku_br02), '.2f'))
ku_br02_skew = 'skew=' + str(format(skew(ku_br02), '.2f'))
ku_br02_type = 'type=' + str(labels[9])

# %%
matplotlib.rcParams.update({'font.size': 12})

plt.figure(figsize=(14, 10))
plt.subplots_adjust(hspace=0.4, wspace=0.4)

label = ['Validation', 'Testing']
bins = 10
ylimit = 0.09
subplot_x = 4
subplot_y = 3

ax = plt.subplot(subplot_x, subplot_y, 1)
plt.hist(ncux_fc, bins = bins, density=True)
plt.plot(lnspc, pdf_g_ncux_fc, label="Norm") # plot it
plt.title('NCUx - Freshman calculas')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(ncux_fc_kurs, xy=(20, 0.075))
ax.annotate(ncux_fc_skew, xy=(20, 0.055))
ax.annotate(ncux_fc_type, xy=(20, 0.035))
#plt.legend(['Training', 'Testing'])

ax = plt.subplot(subplot_x, subplot_y, 2)
plt.hist(ncux_chka, bins = bins, density=True)
plt.plot(lnspc, pdf_g_ncux_chka, label="Norm") # plot it
plt.title('NCUx - CHKA')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(ncux_chka_kurs, xy=(20, 0.075))
ax.annotate(ncux_chka_skew, xy=(20, 0.055))
ax.annotate(ncux_chka_type, xy=(20, 0.035))

ax = plt.subplot(subplot_x, subplot_y, 3)
plt.hist(ncux_chkb, bins = bins, density=True)
plt.plot(lnspc, pdf_g_ncux_chkb, label="Norm") # plot it
plt.title('NCUx - CHKB')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(ncux_chkb_kurs, xy=(20, 0.075))
ax.annotate(ncux_chkb_skew, xy=(20, 0.055))
ax.annotate(ncux_chka_type, xy=(20, 0.035))

#plt.subplot(subplot_x, subplot_y, 4)
#plt.hist(pdf_g_ncux_pre, bins = bins, density=True)
#plt.plot(lnspc, pdf_g_ncux_pre, label="Norm") # plot it
#plt.title('NCUx - PRE')
#plt.ylabel('Probability')
#plt.xlabel('Final Score')
#plt.xlim(0, 100)
#plt.ylim(0, ylimit)



ax = plt.subplot(subplot_x, subplot_y, 5)
plt.hist(cycu_1031sp, bins = bins, density=True)
plt.plot(lnspc, pdf_g_cycu_1031sp, label="Norm") # plot it
plt.title('CYCU - 1031SP')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(cycu_1031sp_kurs, xy=(20, 0.075))
ax.annotate(cycu_1031sp_skew, xy=(20, 0.055))
ax.annotate(cycu_1031sp_type, xy=(20, 0.035))

ax = plt.subplot(subplot_x, subplot_y, 6)
plt.hist(cycu_1041sp, bins = bins, density=True)
plt.plot(lnspc, pdf_g_cycu_1041sp, label="Norm") # plot it
plt.title('CYCU - 1041SP')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(cycu_1041sp_kurs, xy=(20, 0.075))
ax.annotate(cycu_1041sp_skew, xy=(20, 0.055))
ax.annotate(cycu_1041sp_type, xy=(20, 0.035))

ax = plt.subplot(subplot_x, subplot_y, 7)
plt.hist(cycu_1051sp, bins = bins, density=True)
plt.plot(lnspc, pdf_g_cycu_1051sp, label="Norm") # plot it
plt.title('CYCU - 1051SP')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(cycu_1051sp_kurs, xy=(20, 0.075))
ax.annotate(cycu_1051sp_skew, xy=(20, 0.055))
ax.annotate(cycu_1051sp_type, xy=(20, 0.035))

ax = plt.subplot(subplot_x, subplot_y, 8)
plt.hist(cycu_1042os, bins = bins, density=True)
plt.plot(lnspc, pdf_g_cycu_1042os, label="Norm") # plot it
plt.title('CYCU - 1042OS')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(cycu_1042os_kurs, xy=(20, 0.075))
ax.annotate(cycu_1042os_skew, xy=(20, 0.055))
ax.annotate(cycu_1042os_type, xy=(20, 0.035))

ax = plt.subplot(subplot_x, subplot_y, 9)
plt.hist(cycu_1052os, bins = bins, density=True)
plt.plot(lnspc, pdf_g_cycu_1042os, label="Norm") # plot it
plt.title('CYCU - 1052OS')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(cycu_1052os_kurs, xy=(20, 0.075))
ax.annotate(cycu_1052os_skew, xy=(20, 0.055))
ax.annotate(cycu_1052os_type, xy=(20, 0.035))


ax = plt.subplot(subplot_x, subplot_y, 10)
plt.hist(ku_br01, bins = 7, density=True)
plt.plot(lnspc, pdf_g_ku01, label="Norm") # plot it
plt.title('KU - BookRoll-1')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(ku_br01_kurs, xy=(20, 0.075))
ax.annotate(ku_br01_skew, xy=(20, 0.055))
ax.annotate(ku_br01_type, xy=(20, 0.035))

ax = plt.subplot(subplot_x, subplot_y, 11)
plt.hist(ku_br02, bins = bins, density=True)
plt.plot(lnspc, pdf_g_ku02, label="Norm") # plot it
plt.title('KU - BookRoll-2')
plt.ylabel('Probability')
plt.xlabel('Final Score')
plt.xlim(0, 100)
plt.ylim(0, ylimit)
ax.annotate(ku_br02_kurs, xy=(20, 0.075))
ax.annotate(ku_br02_skew, xy=(20, 0.055))
ax.annotate(ku_br02_type, xy=(20, 0.035))


plt.tight_layout()
plt.savefig('./images/score_distribution.png', dpi=300)

#plt.show()

# %%
colors = ["g.","r.", "c."]
#colors = ["g.","r."]

for i in range(len(X)):
    #print("coordinate:",X[i], "label:", labels[i])
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)


plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()

# %%
# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])

# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
'kurtosis=' + str(format(kurtosis(ku_br02), '.2f'))
# Out:
# 'kurtosis=2.19'
