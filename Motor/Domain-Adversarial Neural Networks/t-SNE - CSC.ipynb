# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
csc_folder = '../datasets/csc-features/'
feature_file = '1Y520240302.csv'

# %%
features = pd.read_csv(csc_folder + feature_file)
# features = features.head(200)
features = features.drop(columns=['Unnamed: 0'])

# %%
# model = TSNE(n_components=2, random_state=0, perplexity=30, learning_rate=5, n_iter=250)
# reduced_data = model.fit_transform(features)

# %%
# reduced_pd = pd.DataFrame(reduced_data)
# # reduced_pd
# plt.scatter(reduced_pd[0], reduced_pd[1], alpha=0.5)
# plt.show()

# %%
plt.plot(features['Acceleration RMS band 0'].head(20000))

# %%
features

# %%
validation_file = '1Y520220400.csv'
features = pd.read_csv(csc_folder + validation_file)
features = features.head(1500)
features = features.drop(columns=['Unnamed: 0'])
principalComponents = pca.transform(features)

# principalComponents
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

plt.scatter(principalDf['principal component 1'], principalDf['principal component 2'], alpha=0.5)
plt.show()

# %%
plt.plot(features['Acceleration RMS band 0'])
