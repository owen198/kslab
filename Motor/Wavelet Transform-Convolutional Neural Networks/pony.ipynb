# %%
import pandas as pd
import matplotlib.pyplot as plt
import pywt
import numpy as np

from obspy.signal.tf_misfit import plot_tfr
from wavelets import WaveletAnalysis
from os import listdir
from os.path import isfile, join
# Out:
# /usr/local/lib/python3.6/dist-packages/obspy/signal/headers.py:93: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   ], align=True)

# %%
b11_pd = pd.read_csv('../datasets/phm-2012/Learning_set/Bearing1_1/acc_00001.csv', header=None)
b11_pd
# Out:
#       0   1   2         3      4      5
# 0     9  39  39   65664.0  0.552 -0.146
# 1     9  39  39   65703.0  0.501 -0.480
# 2     9  39  39   65742.0  0.138  0.435
# 3     9  39  39   65781.0 -0.423  0.240
# 4     9  39  39   65820.0 -0.802  0.020
# ...  ..  ..  ..       ...    ...    ...
# 2555  9  39  39  165470.0  0.044 -0.094
# 2556  9  39  39  165510.0 -0.456  0.486
# 2557  9  39  39  165550.0 -0.885 -0.154
# 2558  9  39  39  165580.0 -0.230 -0.762
# 2559  9  39  39  165620.0 -0.134  0.541
#
# [2560 rows x 6 columns]

# %%
fig, ax = plt.subplots()
ax.plot(b11_pd[4])

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()


import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
img = np.save('123.npy')
plt.imshow(img_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-25852159ed9a> in <module>
#      13 from PIL import Image
#      14 from matplotlib import pyplot as plt
# ---> 15 img_array = np.save('123.npy')
#      16 plt.imshow(img_array)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# TypeError: _save_dispatcher() missing 1 required positional argument: 'arr'

# %%
def plot_wps (t):
    
    # constants for the signal
    A1 = 4.
    t1 = 1.
    f1 = 1.
    phi1 = 0.



    # generate the signal
    H1 = (np.sign(t - t1) + 1) / 2
    st1 = A1 * (t - t1) * np.exp(-2 * (t - t1))
    st1 *= np.cos(2. * np.pi * f1 * (t - t1) + phi1 * np.pi) * H1
    
    return st1



dt = 0.001
fmin = 15
fmax = 8000

# %%
motor = 'Bearing1_1/'
path = '../datasets/phm-2012/Learning_set/' + motor
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
onlyfiles.sort()

# %%
for file in onlyfiles:
    if int(file.split('_')[1].split('.')[0]) % 200 == 0:
        
        print(path+file)
        
        b11_pd = pd.read_csv(path+file, header=None)
        plot_tfr(plot_wps(b11_pd[4].values), dt=dt, fmin=fmin, fmax=fmax)
# Out:
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_00200.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_00400.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_00600.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_00800.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_01000.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_01200.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_01400.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_01600.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_01800.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_02000.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_02200.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_02400.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_02600.csv
# ../datasets/phm-2012/Learning_set/Bearing1_1/acc_02800.csv

# %%
# Out:
# False
